# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('Dataset_A3B_OH_343.csv')
df
# Out:
#         Element  M-At No.  M-At wt.  M-Density    M-M.P  M-B.P  M-Enth.fus  \
# 0       Au3M-Ni        79    196.96      19.30  1337.33   3129        12.5
# 1       Au3M-Zn        79    196.96      19.30  1337.33   3129        12.5
# 2       Au3M-Ru        79    196.96      19.30  1337.33   3129        12.5
# 3       Au3M-Rh        79    196.96      19.30  1337.33   3129        12.5
# 4       Au3M-Pd        79    196.96      19.30  1337.33   3129        12.5
# ..          ...       ...       ...        ...      ...    ...         ...
# 337  Re-Re3M-Ta        75    186.21      21.02  3459.00   5869        33.0
# 338   Re-Re3M-W        75    186.21      21.02  3459.00   5869        33.0
# 339  Re-Re3M-Os        75    186.21      21.02  3459.00   5869        33.0
# 340  Re-Re3M-Ir        75    186.21      21.02  3459.00   5869        33.0
# 341  Re-Re3M-Pt        75    186.21      21.02  3459.00   5869        33.0
#
#      M-Enth.atom  M-Enth.vap  M-Sp.ht Cap  ...  Elec.-ve  Surface.E  \
# 0            368         330        129.1  ...      1.91       1.92
# 1            368         330        129.1  ...      1.65       0.33
# 2            368         330        129.1  ...      2.20       2.60
# 3            368         330        129.1  ...      2.28       1.98
# 4            368         330        129.1  ...      2.20       1.36
# ..           ...         ...          ...  ...       ...        ...
# 337          776         705        137.0  ...      1.50       2.34
# 338          776         705        137.0  ...      2.36       3.23
# 339          776         705        137.0  ...      2.20       2.95
# 340          776         705        137.0  ...      2.20       2.36
# 341          776         705        137.0  ...      2.28       1.49
#
#      1st Ion E  cova .radii  At.radii  Group  Period  Work F.  Elec.Aff  \
# 0        737.1          121       149   10.0       4     5.24     112.0
# 1        906.4          122       142   12.0       4     3.63     -58.0
# 2        710.2          126       178    8.0       5     4.65     101.3
# 3        719.7          135       173    9.0       5     5.20     109.7
# 4        804.4          131       169   10.0       5     5.47      53.7
# ..         ...          ...       ...    ...     ...      ...       ...
# 337      761.0          170       200    5.0       6     4.00      31.0
# 338      770.0          162       193    6.0       6     4.45      78.6
# 339      840.0          128       185    8.0       6     5.93     106.1
# 340      880.0          137       180    9.0       6     5.76     151.0
# 341      870.0          136       177   10.0       6     5.97     205.3
#
#        OH_B.E
# 0    1.496072
# 1    1.398238
# 2    1.372716
# 3    1.527600
# 4    1.484960
# ..        ...
# 337 -0.240743
# 338 -0.193473
# 339  0.087294
# 340  0.001003
# 341 -0.062437
#
# [342 rows x 38 columns]

# %%
df2=df.iloc[0:69,1:38]
df2
# Out:
#     M-At No.  M-At wt.  M-Density    M-M.P  M-B.P  M-Enth.fus  M-Enth.atom  \
# 0         79    196.96      19.30  1337.33   3129        12.5          368
# 1         79    196.96      19.30  1337.33   3129        12.5          368
# 2         79    196.96      19.30  1337.33   3129        12.5          368
# 3         79    196.96      19.30  1337.33   3129        12.5          368
# 4         79    196.96      19.30  1337.33   3129        12.5          368
# ..       ...       ...        ...      ...    ...         ...          ...
# 64        77    192.22      22.56  2739.00   4701        26.0          671
# 65        77    192.22      22.56  2739.00   4701        26.0          671
# 66        77    192.22      22.56  2739.00   4701        26.0          671
# 67        77    192.22      22.56  2739.00   4701        26.0          671
# 68        77    192.22      22.56  2739.00   4701        26.0          671
#
#     M-Enth.vap  M-Sp.ht Cap  M-Elec.-ve  ...  Elec.-ve  Surface.E  1st Ion E  \
# 0          330        129.1        2.54  ...      1.91       1.92     737.10
# 1          330        129.1        2.54  ...      1.65       0.33     906.40
# 2          330        129.1        2.54  ...      2.20       2.60     710.20
# 3          330        129.1        2.54  ...      2.28       1.98     719.70
# 4          330        129.1        2.54  ...      2.20       1.36     804.40
# ..         ...          ...         ...  ...       ...        ...        ...
# 64         560        131.0        2.20  ...      1.90       2.57     760.00
# 65         560        131.0        2.20  ...      2.20       2.95     840.00
# 66         560        131.0        2.20  ...      2.28       1.49     870.00
# 67         560        131.0        2.20  ...      2.54       0.74     890.13
# 68         560        131.0        2.20  ...      2.02       0.17     703.00
#
#     cova .radii  At.radii  Group  Period  Work F.  Elec.Aff    OH_B.E
# 0           121       149   10.0       4     5.24     112.0  1.496072
# 1           122       142   12.0       4     3.63     -58.0  1.398238
# 2           126       178    8.0       5     4.65     101.3  1.372716
# 3           135       173    9.0       5     5.20     109.7  1.527600
# 4           131       169   10.0       5     5.47      53.7  1.484960
# ..          ...       ...    ...     ...      ...       ...       ...
# 64          159       188    7.0       6     4.72      14.5  0.704786
# 65          128       185    8.0       6     5.93     106.1  0.679329
# 66          136       177   10.0       6     5.97     205.3  0.531434
# 67          136       174   11.0       6     5.41     222.8  0.523295
# 68          148       143   15.0       6     4.34      91.2  0.291225
#
# [69 rows x 37 columns]

# %%
print(df2.columns.tolist())
# Out:
# ['M-At No.', 'M-At wt.', 'M-Density', 'M-M.P', 'M-B.P', 'M-Enth.fus', 'M-Enth.atom', 'M-Enth.vap', 'M-Sp.ht Cap', 'M-Elec.-ve', 'M-Surface.E', 'M-1st Ion E', 'M-cova .radii', 'M-At.radii', 'M-Group', 'M-Period', 'M-Work F.', 'M-Elec.Aff', 'At No.', 'At wt.', 'Density', 'M.P', 'B.P', 'Enth.fus', 'Enth.atom', 'Enth.vap', 'Sp.ht Cap', 'Elec.-ve', 'Surface.E', '1st Ion E', 'cova .radii', 'At.radii', 'Group', 'Period', 'Work F.', 'Elec.Aff', 'OH_B.E']

# %%
X= df2
y= df2['OH_B.E']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=0)

X_train.shape, X_test.shape
# Out:
# ((48, 37), (21, 37))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df3 = df2.drop(labels=["OH_B.E"], axis=1)
df3
# Out:
#     M-At No.  M-At wt.  M-Density    M-M.P  M-B.P  M-Enth.fus  M-Enth.atom  \
# 0         79    196.96      19.30  1337.33   3129        12.5          368
# 1         79    196.96      19.30  1337.33   3129        12.5          368
# 2         79    196.96      19.30  1337.33   3129        12.5          368
# 3         79    196.96      19.30  1337.33   3129        12.5          368
# 4         79    196.96      19.30  1337.33   3129        12.5          368
# ..       ...       ...        ...      ...    ...         ...          ...
# 64        77    192.22      22.56  2739.00   4701        26.0          671
# 65        77    192.22      22.56  2739.00   4701        26.0          671
# 66        77    192.22      22.56  2739.00   4701        26.0          671
# 67        77    192.22      22.56  2739.00   4701        26.0          671
# 68        77    192.22      22.56  2739.00   4701        26.0          671
#
#     M-Enth.vap  M-Sp.ht Cap  M-Elec.-ve  ...  Sp.ht Cap  Elec.-ve  Surface.E  \
# 0          330        129.1        2.54  ...      445.0      1.91       1.92
# 1          330        129.1        2.54  ...      388.0      1.65       0.33
# 2          330        129.1        2.54  ...      238.0      2.20       2.60
# 3          330        129.1        2.54  ...      240.0      2.28       1.98
# 4          330        129.1        2.54  ...      240.0      2.20       1.36
# ..         ...          ...         ...  ...        ...       ...        ...
# 64         560        131.0        2.20  ...      137.0      1.90       2.57
# 65         560        131.0        2.20  ...      130.0      2.20       2.95
# 66         560        131.0        2.20  ...      133.0      2.28       1.49
# 67         560        131.0        2.20  ...      129.1      2.54       0.74
# 68         560        131.0        2.20  ...      122.0      2.02       0.17
#
#     1st Ion E  cova .radii  At.radii  Group  Period  Work F.  Elec.Aff
# 0      737.10          121       149   10.0       4     5.24     112.0
# 1      906.40          122       142   12.0       4     3.63     -58.0
# 2      710.20          126       178    8.0       5     4.65     101.3
# 3      719.70          135       173    9.0       5     5.20     109.7
# 4      804.40          131       169   10.0       5     5.47      53.7
# ..        ...          ...       ...    ...     ...      ...       ...
# 64     760.00          159       188    7.0       6     4.72      14.5
# 65     840.00          128       185    8.0       6     5.93     106.1
# 66     870.00          136       177   10.0       6     5.97     205.3
# 67     890.13          136       174   11.0       6     5.41     222.8
# 68     703.00          148       143   15.0       6     4.34      91.2
#
# [69 rows x 36 columns]

# %% [markdown]
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(20,20))
# cor = df3.corr()
# G=sns.heatmap(cor,annot=True,cmap="RdYlBu")
# plt.show()

# %%
X = df3
y = df2['OH_B.E']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=0)

X_train.shape, X_test.shape
# Out:
# ((48, 36), (21, 36))

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score
print("r2 on test data is",   r2_score(y_test, y_predict))
# Out:
# r2 on test data is 0.8242208684728907

# %%
print("RMSE:"+str(np.sqrt(mean_squared_error(y_test, y_predict))))
# Out:
# RMSE:0.22906527244259625

# %%
H_params = model.get_params()
H_params
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': 0.5,
#  'booster': 'gbtree',
#  'callbacks': None,
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'gamma': 0,
#  'gpu_id': -1,
#  'grow_policy': 'depthwise',
#  'importance_type': None,
#  'interaction_constraints': '',
#  'learning_rate': 0.300000012,
#  'max_bin': 256,
#  'max_cat_to_onehot': 4,
#  'max_delta_step': 0,
#  'max_depth': 6,
#  'max_leaves': 0,
#  'min_child_weight': 1,
#  'missing': nan,
#  'monotone_constraints': '()',
#  'n_estimators': 100,
#  'n_jobs': 0,
#  'num_parallel_tree': 1,
#  'predictor': 'auto',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'sampling_method': 'uniform',
#  'scale_pos_weight': 1,
#  'subsample': 1,
#  'tree_method': 'exact',
#  'validate_parameters': 1,
#  'verbosity': None}

# %%
plt.scatter(y_test, y_predict)
plt.plot([-2,2], [-2,2],)

# %%
df_pred = pd.read_csv('Cu_based_bi_OH_BE.csv')
df_pred
selected_columns = df_pred[["Element"]]
new_df = selected_columns.copy()

# %%
x = df_pred.drop(labels=["Element","OH_B.E"], axis=1)
x
# Out:
#     M-At No.  M-At wt.  M-Density  M-M.P  M-B.P  M-Enth.fus  M-Enth.atom  \
# 0         29    63.546       8.96   1357   2835        13.1          338
# 1         29    63.546       8.96   1357   2835        13.1          338
# 2         29    63.546       8.96   1357   2835        13.1          338
# 3         29    63.546       8.96   1357   2835        13.1          338
# 4         29    63.546       8.96   1357   2835        13.1          338
# 5         29    63.546       8.96   1357   2835        13.1          338
# 6         29    63.546       8.96   1357   2835        13.1          338
# 7         29    63.546       8.96   1357   2835        13.1          338
# 8         29    63.546       8.96   1357   2835        13.1          338
# 9         29    63.546       8.96   1357   2835        13.1          338
# 10        29    63.546       8.96   1357   2835        13.1          338
# 11        29    63.546       8.96   1357   2835        13.1          338
# 12        29    63.546       8.96   1357   2835        13.1          338
# 13        29    63.546       8.96   1357   2835        13.1          338
# 14        29    63.546       8.96   1357   2835        13.1          338
# 15        29    63.546       8.96   1357   2835        13.1          338
# 16        29    63.546       8.96   1357   2835        13.1          338
# 17        29    63.546       8.96   1357   2835        13.1          338
# 18        29    63.546       8.96   1357   2835        13.1          338
# 19        29    63.546       8.96   1357   2835        13.1          338
# 20        29    63.546       8.96   1357   2835        13.1          338
# 21        29    63.546       8.96   1357   2835        13.1          338
# 22        29    63.546       8.96   1357   2835        13.1          338
# 23        29    63.546       8.96   1357   2835        13.1          338
# 24        29    63.546       8.96   1357   2835        13.1          338
# 25        29    63.546       8.96   1357   2835        13.1          338
#
#     M-Enth.vap  M-Sp.ht Cap  M-Elec.-ve  ...  Sp.ht Cap  Elec.-ve  Surface.E  \
# 0          300        384.4         1.9  ...      567.0      1.36       1.20
# 1          300        384.4         1.9  ...      520.0      1.54       1.93
# 2          300        384.4         1.9  ...      489.0      1.63       2.38
# 3          300        384.4         1.9  ...      448.0      1.66       3.22
# 4          300        384.4         1.9  ...      479.0      1.55       3.39
# 5          300        384.4         1.9  ...      421.0      1.88       2.11
# 6          300        384.4         1.9  ...      445.0      1.91       1.92
# 7          300        384.4         1.9  ...      388.0      1.65       0.33
# 8          300        384.4         1.9  ...      371.0      1.81       0.48
# 9          300        384.4         1.9  ...      298.0      1.22       1.00
# 10         300        384.4         1.9  ...      278.0      1.33       1.60
# 11         300        384.4         1.9  ...      265.0      1.60       2.06
# 12         300        384.4         1.9  ...      251.0      2.16       2.78
# 13         300        384.4         1.9  ...      238.0      2.20       2.60
# 14         300        384.4         1.9  ...      240.0      2.28       1.98
# 15         300        384.4         1.9  ...      240.0      2.20       1.36
# 16         300        384.4         1.9  ...      235.0      1.93       0.76
# 17         300        384.4         1.9  ...      217.0      1.96       0.54
# 18         300        384.4         1.9  ...      140.0      1.50       2.34
# 19         300        384.4         1.9  ...      137.0      1.90       2.57
# 20         300        384.4         1.9  ...      130.0      2.20       2.95
# 21         300        384.4         1.9  ...      131.0      2.20       2.36
# 22         300        384.4         1.9  ...      133.0      2.28       1.49
# 23         300        384.4         1.9  ...      129.1      2.54       0.74
# 24         300        384.4         1.9  ...      904.0      1.61       0.80
# 25         300        384.4         1.9  ...      710.0      1.90       1.30
#
#     1st Ion E  cova .radii  At.radii  Group  Period  Work F.  Elec.Aff
# 0      633.10          170       184      3       4    3.500    18.100
# 1      658.80          160       176      4       4    4.330     7.600
# 2      650.90          153       171      5       4    4.300    50.600
# 3      652.90          139       166      6       4    4.500    64.300
# 4      717.30          139       161      7       4    4.100   -50.000
# 5      760.40          126       152      9       4    5.000    63.700
# 6      737.10          121       149     10       4    5.240   112.000
# 7      906.40          122       142     12       4    3.630   -58.000
# 8      578.80          122       136     13       4    4.320    28.900
# 9      600.00          190       212      3       5    3.183    29.600
# 10     640.10          175       206      4       5    4.050    41.100
# 11     652.10          164       198      5       5    4.360    86.100
# 12     684.30          154       190      6       5    4.520    71.900
# 13     710.20          126       178      8       5    4.650   101.300
# 14     719.70          135       173      9       5    5.200   109.700
# 15     804.40          131       169     10       5    5.470    53.700
# 16     731.00          145       165     11       5    4.630   125.600
# 17     708.60          139       145     14       5    4.420   107.300
# 18     761.00          170       200      5       6    4.000    31.000
# 19     760.00          159       188      7       6    4.720    14.500
# 20     840.00          128       185      8       6    5.930   106.100
# 21     880.00          137       180      9       6    5.760   151.000
# 22     870.00          136       177     10       6    5.970   205.300
# 23     890.13          136       174     11       6    5.410   222.800
# 24     577.50          121       118     13       3    4.040    42.500
# 25     786.50          111       111     14       3    4.637   134.068
#
# [26 rows x 36 columns]

# %%
model.predict(x)
# Out:
# array([-0.8025214 , -0.27404806, -0.2773089 ,  0.11512286,  0.22119562,
#         0.49027085,  0.48004702,  0.2417627 ,  0.3700893 , -0.9385915 ,
#        -0.9385915 , -0.20871086, -0.05016159,  0.54401314,  0.6024143 ,
#         0.50720763,  0.5274211 ,  0.15873632, -0.7397515 ,  0.14550392,
#         0.4396949 ,  0.47202072,  0.4507174 ,  0.4100875 ,  0.22879672,
#         0.45068613], dtype=float32)

# %%
p = model.predict(x)
p = pd.DataFrame(p)
p
# Out:
#            0
# 0  -0.802521
# 1  -0.274048
# 2  -0.277309
# 3   0.115123
# 4   0.221196
# 5   0.490271
# 6   0.480047
# 7   0.241763
# 8   0.370089
# 9  -0.938591
# 10 -0.938591
# 11 -0.208711
# 12 -0.050162
# 13  0.544013
# 14  0.602414
# 15  0.507208
# 16  0.527421
# 17  0.158736
# 18 -0.739752
# 19  0.145504
# 20  0.439695
# 21  0.472021
# 22  0.450717
# 23  0.410087
# 24  0.228797
# 25  0.450686

# %%
print(model.feature_importances_)
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='bar')
plt.show()
# Out:
# [3.6076233e-02 0.0000000e+00 2.3406539e-04 7.8458972e-02 0.0000000e+00
#  6.3766824e-06 0.0000000e+00 0.0000000e+00 3.3801816e-06 5.4058444e-01
#  8.4737830e-02 4.6594534e-05 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  0.0000000e+00 1.1781689e-04 1.9838860e-06 2.3844691e-03 4.6902001e-04
#  1.2801491e-03 1.8355970e-03 1.2270291e-02 2.1644393e-05 9.3786484e-03
#  4.9913633e-05 3.7441659e-04 1.3149421e-01 2.8499987e-02 6.3540884e-03
#  4.8303243e-02 5.7906628e-04 4.5648357e-03 0.0000000e+00 1.1255085e-02
#  6.1770400e-04]

# %%
from scipy.stats import uniform, randint
from sklearn.linear_model import Lasso
from scipy.stats.qmc import Sobol

# %%
from sklearn.model_selection import RandomizedSearchCV , GridSearchCV
import xgboost as xgb

params = { 'max_depth': np.arange(8,15,1),                      #10
           'learning_rate': np.arange(0.01,0.1, 0.01),         #0.071
           'subsample': np.arange(0.7, 1.0, 0.01),              #0.75
           #'colsample_bytree': np.arange(0.9, 1, 0.02),         #0.82
           'min_child_weight': np.arange(5,15, 1),
           #'colsample_bylevel': np.arange(0.9, 1, 0.02),        #0.72
           'n_estimators': np.arange(400,1000,25),                #116
           #'reg_alpha': uniform(0.1,5),                     #0.8612124738904751
           #'reg_lambda': uniform(0.1,5),                      #115.01455430429743  
         }
sobol_sequence = Sobol(1)
lasso = Lasso()
# number of times random search is run
n = 50                                       # n=20    #n_iter=50  #cv=10

# %%
xgbr = xgb.XGBRegressor(seed=20)
average = np.array([0]*36, dtype=np.float64)
feature_importances = []

nth_run = 1
rmse_values_test = []
rmse_values_train = []
avg = 0

for i in range(n):   
    clf = RandomizedSearchCV(estimator=xgbr,
                             param_distributions=params,
                             scoring='neg_mean_squared_error',
                             n_iter=50,cv=10,random_state=np.random.RandomState(int(sobol_sequence.random(1)[0] * 2**31)),
                             verbose=1)
    clf.fit(X_train,y_train)
    
    print(f"Run {i + 1}: Best Estimator: {clf.best_estimator_}")
    
    if (i + 1) % nth_run == 0:
        # Predictions on test set
        y_pred_test = clf.predict(X_test)
        mse_test = mean_squared_error(y_test, y_pred_test)
        rmse_test = np.sqrt(mse_test)
        rmse_values_test.append(rmse_test)
        
        # Predictions on training set
        y_pred_train = clf.predict(X_train)
        mse_train = mean_squared_error(y_train, y_pred_train)
        rmse_train = np.sqrt(mse_train)
        rmse_values_train.append(rmse_train)

        print(f"RMSE for every {nth_run}th run - Training: {rmse_train}, Test: {rmse_test}")
        nth_run += 1
    
    average += clf.best_estimator_.feature_importances_
    feature_importances.append(clf.best_estimator_.feature_importances_)
average = average/n
avg = avg/n
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 1: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.06999999999999999, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=10, max_leaves=0,
#              min_child_weight=6, missing=nan, monotone_constraints='()',
#              n_estimators=525, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 1th run - Training: 0.003934987164269452, Test: 0.19046584517135834
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 2: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=775, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 2th run - Training: 0.0018336900128898665, Test: 0.1949379536912453
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 3: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.02, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=13, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=625, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 3th run - Training: 0.029813334289577047, Test: 0.1859945312032675
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 4: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=13, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=700, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 4th run - Training: 0.01465800163493565, Test: 0.18467579964322076
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 5: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=13, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=650, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 5th run - Training: 0.02025726963345303, Test: 0.19671233253912718
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 6: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=13, max_leaves=0, min_child_weight=5,
#              missing=nan, monotone_constraints='()', n_estimators=525, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 6th run - Training: 0.028082693263872728, Test: 0.2100540832968433
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 7: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=8, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=575, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 7th run - Training: 0.01714851210058626, Test: 0.1828100206752175
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 8: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=13, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=550, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 8th run - Training: 0.009446128959143244, Test: 0.18891075470697188
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 9: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=825, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 9th run - Training: 0.011382583746113248, Test: 0.1852003812712798
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 10: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=875, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 10th run - Training: 0.013360093963256657, Test: 0.19781423893938124
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 11: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=975, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 11th run - Training: 0.006854004519563646, Test: 0.18594963421468852
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 12: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=775, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 12th run - Training: 0.014381324636671668, Test: 0.19619904161886326
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 13: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=900, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 13th run - Training: 0.009569941780586679, Test: 0.18623816733570875
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 14: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=11, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=850, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 14th run - Training: 0.0075129853789014465, Test: 0.2085667792507698
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 15: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=900, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 15th run - Training: 0.003908288987234131, Test: 0.191466563789621
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 16: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=550, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 16th run - Training: 0.013744389084402906, Test: 0.21059889919985406
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 17: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=550, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 17th run - Training: 0.002688618510746496, Test: 0.19779299340800488
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 18: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.060000000000000005, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=8, max_leaves=0,
#              min_child_weight=5, missing=nan, monotone_constraints='()',
#              n_estimators=525, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 18th run - Training: 0.010814004831685483, Test: 0.2144900780332265
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 19: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=11, max_leaves=0, min_child_weight=5,
#              missing=nan, monotone_constraints='()', n_estimators=725, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 19th run - Training: 0.012200905403960228, Test: 0.2155368874084175
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 20: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=600, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 20th run - Training: 0.019941019441411984, Test: 0.21060927278025318
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 21: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=825, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 21th run - Training: 0.006549947170754374, Test: 0.18558684376338527
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 22: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.02, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=625, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 22th run - Training: 0.026552034847998927, Test: 0.1830265654568928
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 23: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=5,
#              missing=nan, monotone_constraints='()', n_estimators=900, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 23th run - Training: 0.007794162767619314, Test: 0.21052531356790244
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 24: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=550, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 24th run - Training: 0.007109831599801543, Test: 0.18533283944735615
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 25: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.09, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=800, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 25th run - Training: 0.0014669630341068811, Test: 0.20174238510539078
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 26: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=8, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=600, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 26th run - Training: 0.012990483270897774, Test: 0.18923811217693848
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 27: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.06999999999999999, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=11, max_leaves=0,
#              min_child_weight=6, missing=nan, monotone_constraints='()',
#              n_estimators=850, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 27th run - Training: 0.0025510474762325637, Test: 0.19826942226368277
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 28: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=700, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 28th run - Training: 0.014337074316054958, Test: 0.18526817038297605
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 29: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=700, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 29th run - Training: 0.019390947777402762, Test: 0.20812923464015873
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 30: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.060000000000000005, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=12, max_leaves=0,
#              min_child_weight=6, missing=nan, monotone_constraints='()',
#              n_estimators=875, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 30th run - Training: 0.0023007783376690714, Test: 0.18526080674605683
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 31: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.060000000000000005, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=10, max_leaves=0,
#              min_child_weight=6, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 31th run - Training: 0.009888345770273052, Test: 0.20339267156415047
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 32: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=975, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 32th run - Training: 0.0017195107821835563, Test: 0.19489089712850935
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 33: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=575, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 33th run - Training: 0.013188966726987553, Test: 0.1854283147320982
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 34: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.06999999999999999, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=13, max_leaves=0,
#              min_child_weight=6, missing=nan, monotone_constraints='()',
#              n_estimators=450, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 34th run - Training: 0.005013611460447494, Test: 0.19198989212731726
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 35: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=950, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 35th run - Training: 0.01051230646091551, Test: 0.19624143695235685
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 36: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=625, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 36th run - Training: 0.0029445903739517463, Test: 0.19377810121861447
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 37: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=11, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=925, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 37th run - Training: 0.0035714802812625863, Test: 0.1905486474622406
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 38: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=575, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 38th run - Training: 0.01877757612504408, Test: 0.18415939052233424
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 39: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.09, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=900, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 39th run - Training: 0.001248548190873634, Test: 0.19190907345152083
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 40: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=425, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 40th run - Training: 0.009642276468922914, Test: 0.2100494512914364
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 41: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=425, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 41th run - Training: 0.02004295108336069, Test: 0.18314568092970263
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 42: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=925, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 42th run - Training: 0.0036283311331001015, Test: 0.18601814280635526
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 43: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.060000000000000005, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=10, max_leaves=0,
#              min_child_weight=6, missing=nan, monotone_constraints='()',
#              n_estimators=450, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 43th run - Training: 0.011641575828378043, Test: 0.2031334757001994
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 44: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=800, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 44th run - Training: 0.012340884836562158, Test: 0.193572271609598
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 45: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=600, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 45th run - Training: 0.018258963007586462, Test: 0.18420577700918817
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 46: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=13, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=575, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 46th run - Training: 0.024520937532312378, Test: 0.20373883365385803
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 47: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=575, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 47th run - Training: 0.006532259521476907, Test: 0.18542548892199304
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 48: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.09, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=625, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 48th run - Training: 0.00197719680757912, Test: 0.18951355095398653
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 49: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=8, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=925, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 49th run - Training: 0.008702510532777064, Test: 0.183537268011908
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Run 50: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.02, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=900, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 50th run - Training: 0.018142096461704914, Test: 0.18380377606851547

# %%
feature_importances
# Out:
# [array([3.5041306e-02, 0.0000000e+00, 2.9603068e-03, 5.0418302e-02,
#         0.0000000e+00, 4.8014268e-02, 0.0000000e+00, 0.0000000e+00,
#         2.4675549e-04, 4.2948779e-01, 9.3321137e-02, 6.2491419e-04,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         7.9455674e-03, 5.3410400e-03, 1.2852210e-03, 9.7271526e-04,
#         9.0382114e-04, 5.7605770e-03, 2.8838415e-04, 1.3982308e-03,
#         4.0341318e-03, 5.7948357e-04, 1.7939619e-03, 5.7506632e-02,
#         7.2011454e-03, 2.0788616e-02, 3.3418886e-02, 1.7752443e-02,
#         1.4726295e-01, 0.0000000e+00, 5.9498316e-03, 1.9701524e-02],
#        dtype=float32),
#  array([2.3185790e-02, 0.0000000e+00, 3.2724869e-03, 4.5636613e-02,
#         0.0000000e+00, 3.4406256e-02, 0.0000000e+00, 0.0000000e+00,
#         2.1871873e-03, 3.3781555e-01, 1.9720343e-01, 2.2676429e-03,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#
-03,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         8.86381418e-03, 3.06821684e-03, 8.74371734e-04, 7.67103120e-06,
#         1.38885085e-03, 7.55327614e-03, 4.51479165e-04, 2.80610844e-03,
#         7.53258821e-04, 9.84646613e-05, 1.77063409e-03, 7.42356330e-02,
#         8.18643160e-03, 1.88725535e-02, 2.79146209e-02, 3.57601866e-02,
#         1.74032182e-01, 0.00000000e+00, 6.84356410e-03, 1.98604837e-02],
#        dtype=float32),
#  array([3.09016947e-02, 0.00000000e+00, 2.91244569e-03, 6.57032579e-02,
#         0.00000000e+00, 3.28472331e-02, 0.00000000e+00, 0.00000000e+00,
#         5.67512237e-04, 4.76058692e-01, 6.71773031e-02, 2.56798789e-03,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         7.36191962e-03, 5.29351551e-03, 1.17171544e-03, 1.14668626e-03,
#         1.58467016e-03, 4.17248625e-03, 3.22026579e-04, 1.12345966e-03,
#         2.89632380e-03, 8.20656074e-04, 1.72008108e-03, 4.41808477e-02,
#         4.65939380e-03, 2.31918711e-02, 5.20670302e-02, 1.46343056e-02,
#         1.22662984e-01, 0.00000000e+00, 9.65346396e-03, 2.26003639e-02],
#        dtype=float32),
#  array([3.0644888e-02, 0.0000000e+00, 3.2798082e-03, 4.8015554e-02,
#         0.0000000e+00, 1.2186824e-02, 0.0000000e+00, 0.0000000e+00,
#         6.1228691e-04, 3.4809795e-01, 1.8040416e-01, 3.1129754e-04,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         8.7566078e-03, 5.8633136e-03, 6.2630849e-04, 3.0279436e-04,
#         1.9568442e-03, 4.6078772e-03, 3.6293274e-04, 2.7321819e-03,
#         2.2598372e-03, 2.1088149e-03, 1.1365332e-03, 6.0532905e-02,
#         7.1753785e-03, 1.4495930e-02, 1.9339090e-02, 3.2458764e-02,
#         1.8558943e-01, 0.0000000e+00, 7.1306019e-03, 1.9011198e-02],
#        dtype=float32),
#  array([3.2827482e-02, 0.0000000e+00, 4.4616000e-03, 4.6795450e-02,
#         0.0000000e+00, 1.1415719e-02, 0.0000000e+00, 0.0000000e+00,
#         7.4031530e-04, 3.6618197e-01, 1.7749837e-01, 6.7007211e-03,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         9.8511251e-03, 7.2284089e-03, 1.0214170e-03, 1.7297847e-04,
#         2.9960407e-03, 7.2012790e-03, 1.0131946e-03, 3.1028215e-03,
#         3.7418250e-03, 6.6363276e-04, 1.1055622e-03, 5.5154186e-02,
#         9.7027440e-03, 1.7450197e-02, 2.9912010e-02, 4.9198490e-02,
#         1.2634787e-01, 0.0000000e+00, 1.0622672e-02, 1.6891789e-02],
#        dtype=float32)]

# %%
np.min(rmse_values_test), np.max(rmse_values_test)
# Out:
# (0.1828100206752175, 0.2155368874084175)

# %%
np.min(rmse_values_train), np.max(rmse_values_train)
# Out:
# (0.001248548190873634, 0.029813334289577047)

# %%
mean_rmse_test = np.mean(rmse_values_test)
print(f"Mean RMSE: {mean_rmse_test}")
# Out:
# Mean RMSE: 0.19411772187687887

# %%
mean_rmse_train = np.mean(rmse_values_train)
print(f"Mean RMSE: {mean_rmse_train}")
# Out:
# Mean RMSE: 0.01109741934655

# %%
avg
# Out:
# 0.0

# %%
y_pred = clf.best_estimator_.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# 0.18380377606851547

# %%
from sklearn.metrics import r2_score

# Add this snippet at the end of your code
y_pred_test = clf.best_estimator_.predict(X_test)
r2 = r2_score(y_test, y_pred_test)

print(f"Best R² score for the test set: {r2}")
# Out:
# Best R² score for the test set: 0.8868231329879999

# %%
average
# Out:
# array([2.67638288e-02, 0.00000000e+00, 4.73174751e-03, 4.29383180e-02,
#        0.00000000e+00, 2.20526323e-02, 0.00000000e+00, 0.00000000e+00,
#        6.97990943e-04, 3.25184444e-01, 1.99002783e-01, 1.34466948e-02,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.08877933e-03, 6.36383268e-03, 1.09853473e-03, 2.89116100e-04,
#        2.01984027e-03, 5.73646542e-03, 8.39548079e-04, 3.63882815e-03,
#        2.85519770e-03, 1.30812186e-03, 1.42721324e-03, 5.17122236e-02,
#        5.97734926e-03, 1.75449103e-02, 2.92764545e-02, 3.93396761e-02,
#        1.66444174e-01, 0.00000000e+00, 8.57964513e-03, 1.36416547e-02])

# %%
plt.figure(figsize=(12, 8))
plt.bar(x=range(36), height=np.mean(feature_importances, axis=0), yerr=np.std(feature_importances, axis=0))
plt.xticks(ticks = range(36), labels=X_train.columns, rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x1e00bbe7910>,
#   <matplotlib.axis.XTick at 0x1e00bbe7640>,
#   <matplotlib.axis.XTick at 0x1e070d1c460>,
#   <matplotlib.axis.XTick at 0x1e00bbfd940>,
#   <matplotlib.axis.XTick at 0x1e00ba476d0>,
#   <matplotlib.axis.XTick at 0x1e00ba34c10>,
#   <matplotlib.axis.XTick at 0x1e00ba34a30>,
#   <matplotlib.axis.XTick at 0x1e00ba34250>,
#   <matplotlib.axis.XTick at 0x1e00b9dee80>,
#   <matplotlib.axis.XTick at 0x1e00ba34790>,
#   <matplotlib.axis.XTick at 0x1e00ba47d60>,
#   <matplotlib.axis.XTick at 0x1e00b9de280>,
#   <matplotlib.axis.XTick at 0x1e00ba13880>,
#   <matplotlib.axis.XTick at 0x1e00ba13f10>,
#   <matplotlib.axis.XTick at 0x1e00ba5e850>,
#   <matplotlib.axis.XTick at 0x1e00bc7a2b0>,
#   <matplotlib.axis.XTick at 0x1e00ba131c0>,
#   <matplotlib.axis.XTick at 0x1e00b9de0a0>,
#   <matplotlib.axis.XTick at 0x1e00bc7a3a0>,
#   <matplotlib.axis.XTick at 0x1e00bc7adf0>,
#   <matplotlib.axis.XTick at 0x1e00bc74580>,
#   <matplotlib.axis.XTick at 0x1e00bc74cd0>,
#   <matplotlib.axis.XTick at 0x1e00bc86460>,
#   <matplotlib.axis.XTick at 0x1e00bc74670>,
#   <matplotlib.axis.XTick at 0x1e00bc7aee0>,
#   <matplotlib.axis.XTick at 0x1e00bbfd400>,
#   <matplotlib.axis.XTick at 0x1e00bc86a90>,
#   <matplotlib.axis.XTick at 0x1e00bc89220>,
#   <matplotlib.axis.XTick at 0x1e00bc89970>,
#   <matplotlib.axis.XTick at 0x1e00bc89c10>,
#   <matplotlib.axis.XTick at 0x1e00bc86a60>,
#   <matplotlib.axis.XTick at 0x1e00bc74640>,
#   <matplotlib.axis.XTick at 0x1e00bc8f580>,
#   <matplotlib.axis.XTick at 0x1e00bc8fcd0>,
#   <matplotlib.axis.XTick at 0x1e00bc96460>,
#   <matplotlib.axis.XTick at 0x1e00bc96bb0>],
#  [Text(0, 0, 'M-At No.'),
#   Text(1, 0, 'M-At wt.'),
#   Text(2, 0, 'M-Density'),
#   Text(3, 0, 'M-M.P'),
#   Text(4, 0, 'M-B.P'),
#   Text(5, 0, 'M-Enth.fus'),
#   Text(6, 0, 'M-Enth.atom'),
#   Text(7, 0, 'M-Enth.vap'),
#   Text(8, 0, 'M-Sp.ht Cap'),
#   Text(9, 0, 'M-Elec.-ve'),
#   Text(10, 0, 'M-Surface.E'),
#   Text(11, 0, 'M-1st Ion E'),
#   Text(12, 0, 'M-cova .radii'),
#   Text(13, 0, 'M-At.radii'),
#   Text(14, 0, 'M-Group'),
#   Text(15, 0, 'M-Period'),
#   Text(16, 0, 'M-Work F.'),
#   Text(17, 0, 'M-Elec.Aff'),
#   Text(18, 0, 'At No.'),
#   Text(19, 0, 'At wt.'),
#   Text(20, 0, 'Density'),
#   Text(21, 0, 'M.P'),
#   Text(22, 0, 'B.P'),
#   Text(23, 0, 'Enth.fus'),
#   Text(24, 0, 'Enth.atom'),
#   Text(25, 0, 'Enth.vap'),
#   Text(26, 0, 'Sp.ht Cap'),
#   Text(27, 0, 'Elec.-ve'),
#   Text(28, 0, 'Surface.E'),
#   Text(29, 0, '1st Ion E'),
#   Text(30, 0, 'cova .radii'),
#   Text(31, 0, 'At.radii'),
#   Text(32, 0, 'Group'),
#   Text(33, 0, 'Period'),
#   Text(34, 0, 'Work F.'),
#   Text(35, 0, 'Elec.Aff')])

# %%
len(clf.best_estimator_.feature_importances_)
[0]*24

print("Best parameters:", clf.best_params_)
# Out:
# Best parameters: {'subsample': 0.9200000000000002, 'n_estimators': 900, 'min_child_weight': 6, 'max_depth': 14, 'learning_rate': 0.02}

# %%
print("neg_MSE:", clf.best_score_)
# Out:
# neg_MSE: -0.02718414369562049

# %%
y_pred = clf.best_estimator_.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

rmse
# Out:
# 0.18380377606851547

# %%
y_predict = clf.best_estimator_.predict(X_test)

# %%
y_train_predict = clf.best_estimator_.predict(X_train)
plt.figure(figsize=(12, 8))
plt.scatter(y_train, y_train_predict, facecolors='black', edgecolors='black', s=10)
plt.scatter(y_test, y_predict, marker='s', edgecolors='red',facecolors='pink' ,s=15)
plt.plot([-1,2], [-1,2],)
plt.grid(True)
plt.xlabel('DFT-calculated')
plt.ylabel('Predicted')
plt.title('(d)_0.30')

plt.show
plt.savefig('DFT vs predicted_OH - test_size_0.30_xGBR.jpg',dpi = 500)

# %%
y_train_predict = clf.best_estimator_.predict(X_train)
plt.figure(figsize=(12, 8),dpi=400)
plt.scatter(y_train, y_train_predict, facecolors='black', edgecolors='black', s=30)
plt.scatter(y_test, y_predict, marker='s', edgecolors='red',facecolors='pink' ,s=35)
plt.plot([-1,3], [-1,3],)
plt.grid(False)
plt.xlabel('DFT-calculated', fontsize=25)
plt.ylabel('Predicted', fontsize=25)
plt.title('(d) - Train/Test = 0.70/0.30 ', fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.show
plt.savefig('DFT vs predicted(xGBR) - test_size_0.30.jpg',dpi = 500)

# %%
t = clf.best_estimator_.predict(x)
t = pd.DataFrame(t)
t
# Out:
#            0
# 0  -0.549950
# 1  -0.341247
# 2  -0.101453
# 3   0.083195
# 4  -0.000357
# 5   0.296852
# 6   0.508036
# 7   0.169987
# 8   0.160361
# 9  -0.772946
# 10 -0.859056
# 11 -0.292309
# 12 -0.171211
# 13  0.255708
# 14  0.533605
# 15  0.320454
# 16  0.466952
# 17  0.083229
# 18 -0.650060
# 19  0.168262
# 20  0.310175
# 21  0.510433
# 22  0.542673
# 23  0.491500
# 24 -0.003926
# 25  0.442642

# %%
output_file_OH = 'output_data_OH_xgbr_0.30.xlsx'
t.to_excel(output_file_OH, index=False)
print(f"Data frame converted and saved to '{output_file_OH}'.")
# Out:
# Data frame converted and saved to 'output_data_OH_xgbr_0.30.xlsx'.

# %%
clf.best_estimator_.feature_importances_
plt.figure(figsize=(12, 8))
feat_importances = pd.Series(clf.best_estimator_.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='bar')
plt.xlabel('Features')
plt.ylabel('Importance - scale (0-1)')
plt.show()
plt.savefig('Feature_Importance_best_esti_xgbr_(0.30).jpg', dpi=500)

# %%
# Assuming X is your feature matrix and clf is your trained classifier
# Replace 'dog' and 'cat' with the actual feature names you want to exclude
features_to_exclude = []

# Get feature importances
importances = clf.best_estimator_.feature_importances_

# Create a DataFrame with feature importances
feat_importances = pd.Series(importances, index=X.columns)

# Drop the specified features
feat_importances = feat_importances.drop(features_to_exclude, errors='ignore')

# Plot the feature importances
plt.figure(figsize=(12, 8))
feat_importances.nlargest(20).plot(kind='bar')
plt.xlabel('Features')
plt.ylabel('Importance - scale (0-1)')
plt.show()

# Save the plot
plt.savefig('Feature_Importance_remaining_xgbr_(0.30).jpg', dpi=500)

# %%
avg=np.mean(feature_importances, axis=0)
plt.figure(figsize=(10, 6))
feat_importances = pd.Series(avg, index=X.columns)
feat_importances.nlargest(10).plot(kind='bar')
plt.xlabel('Features')
plt.ylabel('Importance - scale (0-1)')
plt.show()
plt.savefig('Feature_Importance_average_xgbr_(0.30).jpg', dpi=500)

# %%
med=np.median(feature_importances, axis=0)
feat_importances = pd.Series(med, index=X.columns)
feat_importances.nlargest(10).plot(kind='bar')
plt.show()

# %%
std=np.std(feature_importances, axis=0)
plt.figure(figsize=(10, 6))
feat_importances = pd.Series(std, index=X.columns)
feat_importances.nlargest(15).plot(kind='bar')
plt.xlabel('Features')
plt.ylabel('Standard Deviation')
plt.show()
plt.savefig('standard deviation_xgbr_(0.30).jpg', dpi=500)
