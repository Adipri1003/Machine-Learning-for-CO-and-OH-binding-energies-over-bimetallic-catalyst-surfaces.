# %%
import pandas as pd
import numpy as np

# %%
import time
start_time = time.time()

# %%
df= pd.read_csv('DATASET_A3B_CO-without_Cu.csv')
df
# Out:
#      Element  M-At No.  M-At wt.  M-Density    M-M.P  M-B.P  M-Enth.fus  \
# 0    Ag3M-Ti        47    107.87      10.49  1234.93   2435        11.3
# 1     Ag3M-V        47    107.87      10.49  1234.93   2435        11.3
# 2    Ag3M-Cr        47    107.87      10.49  1234.93   2435        11.3
# 3    Ag3M-Mn        47    107.87      10.49  1234.93   2435        11.3
# 4    Ag3M-Co        47    107.87      10.49  1234.93   2435        11.3
# ..       ...       ...       ...        ...      ...    ...         ...
# 151  Ir3M-Re        77    192.22      22.56  2739.00   4701        26.0
# 152  Ir3M-Os        77    192.22      22.56  2739.00   4701        26.0
# 153  Ir3M-Pt        77    192.22      22.56  2739.00   4701        26.0
# 154  Ir3M-Au        77    192.22      22.56  2739.00   4701        26.0
# 155  Ir3M-Bi        77    192.22      22.56  2739.00   4701        26.0
#
#      M-Enth.atom  M-Enth.vap  M-Sp.ht Cap  ...  Elec.-ve  Surface.E  \
# 0            285         255          235  ...      1.54       1.93
# 1            285         255          235  ...      1.63       2.38
# 2            285         255          235  ...      1.66       3.22
# 3            285         255          235  ...      1.55       3.39
# 4            285         255          235  ...      1.88       2.11
# ..           ...         ...          ...  ...       ...        ...
# 151          671         560          131  ...      1.90       2.57
# 152          671         560          131  ...      2.20       2.95
# 153          671         560          131  ...      2.28       1.49
# 154          671         560          131  ...      2.54       0.74
# 155          671         560          131  ...      2.02       0.17
#
#      1st Ion E  cova .radii  At.radii  Group  Period  Work F.  Elec.Aff  \
# 0       658.80          160       176    4.0       4     4.33       7.6
# 1       650.90          153       171    5.0       4     4.30      50.6
# 2       652.90          139       166    6.0       4     4.50      64.3
# 3       717.30          139       161    7.0       4     4.10     -50.0
# 4       760.40          126       152    9.0       4     5.00      63.7
# ..         ...          ...       ...    ...     ...      ...       ...
# 151     760.00          159       188    7.0       6     4.72      14.5
# 152     840.00          128       185    8.0       6     5.93     106.1
# 153     870.00          136       177   10.0       6     5.97     205.3
# 154     890.13          136       174   11.0       6     5.41     222.8
# 155     703.00          148       143   15.0       6     4.34      91.2
#
#        CO_B.E
# 0    0.110488
# 1    0.041306
# 2    0.032003
# 3    0.034649
# 4    0.037391
# ..        ...
# 151 -1.447916
# 152 -1.608018
# 153 -1.956184
# 154 -1.998453
# 155 -1.794044
#
# [156 rows x 38 columns]

# %%
df['CO_B.E'] = df['CO_B.E']

# %%
df2=df.iloc[:,1:38]
df2
# Out:
#      M-At No.  M-At wt.  M-Density    M-M.P  M-B.P  M-Enth.fus  M-Enth.atom  \
# 0          47    107.87      10.49  1234.93   2435        11.3          285
# 1          47    107.87      10.49  1234.93   2435        11.3          285
# 2          47    107.87      10.49  1234.93   2435        11.3          285
# 3          47    107.87      10.49  1234.93   2435        11.3          285
# 4          47    107.87      10.49  1234.93   2435        11.3          285
# ..        ...       ...        ...      ...    ...         ...          ...
# 151        77    192.22      22.56  2739.00   4701        26.0          671
# 152        77    192.22      22.56  2739.00   4701        26.0          671
# 153        77    192.22      22.56  2739.00   4701        26.0          671
# 154        77    192.22      22.56  2739.00   4701        26.0          671
# 155        77    192.22      22.56  2739.00   4701        26.0          671
#
#      M-Enth.vap  M-Sp.ht Cap  M-Elec.-ve  ...  Elec.-ve  Surface.E  1st Ion E  \
# 0           255          235        1.93  ...      1.54       1.93     658.80
# 1           255          235        1.93  ...      1.63       2.38     650.90
# 2           255          235        1.93  ...      1.66       3.22     652.90
# 3           255          235        1.93  ...      1.55       3.39     717.30
# 4           255          235        1.93  ...      1.88       2.11     760.40
# ..          ...          ...         ...  ...       ...        ...        ...
# 151         560          131        2.20  ...      1.90       2.57     760.00
# 152         560          131        2.20  ...      2.20       2.95     840.00
# 153         560          131        2.20  ...      2.28       1.49     870.00
# 154         560          131        2.20  ...      2.54       0.74     890.13
# 155         560          131        2.20  ...      2.02       0.17     703.00
#
#      cova .radii  At.radii  Group  Period  Work F.  Elec.Aff    CO_B.E
# 0            160       176    4.0       4     4.33       7.6  0.110488
# 1            153       171    5.0       4     4.30      50.6  0.041306
# 2            139       166    6.0       4     4.50      64.3  0.032003
# 3            139       161    7.0       4     4.10     -50.0  0.034649
# 4            126       152    9.0       4     5.00      63.7  0.037391
# ..           ...       ...    ...     ...      ...       ...       ...
# 151          159       188    7.0       6     4.72      14.5 -1.447916
# 152          128       185    8.0       6     5.93     106.1 -1.608018
# 153          136       177   10.0       6     5.97     205.3 -1.956184
# 154          136       174   11.0       6     5.41     222.8 -1.998453
# 155          148       143   15.0       6     4.34      91.2 -1.794044
#
# [156 rows x 37 columns]

# %%
print(df2.columns.tolist())
# Out:
# ['M-At No.', 'M-At wt.', 'M-Density', 'M-M.P', 'M-B.P', 'M-Enth.fus', 'M-Enth.atom', 'M-Enth.vap', 'M-Sp.ht Cap', 'M-Elec.-ve', 'M-Surface.E', 'M-1st Ion E', 'M-cova .radii', 'M-At.radii', 'M-Group', 'M-Period', 'M-Work F.', 'M-Elec.Aff', 'At No.', 'At wt.', 'Density', 'M.P', 'B.P', 'Enth.fus', 'Enth.atom', 'Enth.vap', 'Sp.ht Cap', 'Elec.-ve', 'Surface.E', '1st Ion E', 'cova .radii', 'At.radii', 'Group', 'Period', 'Work F.', 'Elec.Aff', 'CO_B.E']

# %%
X= df2
y= df['CO_B.E']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)

X_train.shape, X_test.shape
# Out:
# ((109, 37), (47, 37))

# %% [markdown]
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(30,30))
# cor = df2.corr()
# G=sns.heatmap(cor,annot=True,cmap="RdYlBu")
# plt.show()

# %%
df3 = df2.drop(labels=["CO_B.E","M-Enth.fus", "M-Enth.vap","Enth.fus","Enth.vap","M-Enth.atom","Enth.atom"], axis=1)
df3
# Out:
#      M-At No.  M-At wt.  M-Density    M-M.P  M-B.P  M-Sp.ht Cap  M-Elec.-ve  \
# 0          47    107.87      10.49  1234.93   2435          235        1.93
# 1          47    107.87      10.49  1234.93   2435          235        1.93
# 2          47    107.87      10.49  1234.93   2435          235        1.93
# 3          47    107.87      10.49  1234.93   2435          235        1.93
# 4          47    107.87      10.49  1234.93   2435          235        1.93
# ..        ...       ...        ...      ...    ...          ...         ...
# 151        77    192.22      22.56  2739.00   4701          131        2.20
# 152        77    192.22      22.56  2739.00   4701          131        2.20
# 153        77    192.22      22.56  2739.00   4701          131        2.20
# 154        77    192.22      22.56  2739.00   4701          131        2.20
# 155        77    192.22      22.56  2739.00   4701          131        2.20
#
#      M-Surface.E  M-1st Ion E  M-cova .radii  ...  Sp.ht Cap  Elec.-ve  \
# 0          1.170        731.0            145  ...      520.0      1.54
# 1          1.170        731.0            145  ...      489.0      1.63
# 2          1.170        731.0            145  ...      448.0      1.66
# 3          1.170        731.0            145  ...      479.0      1.55
# 4          1.170        731.0            145  ...      421.0      1.88
# ..           ...          ...            ...  ...        ...       ...
# 151        2.971        880.0            137  ...      137.0      1.90
# 152        2.971        880.0            137  ...      130.0      2.20
# 153        2.971        880.0            137  ...      133.0      2.28
# 154        2.971        880.0            137  ...      129.1      2.54
# 155        2.971        880.0            137  ...      122.0      2.02
#
#      Surface.E  1st Ion E  cova .radii  At.radii  Group  Period  Work F.  \
# 0         1.93     658.80          160       176    4.0       4     4.33
# 1         2.38     650.90          153       171    5.0       4     4.30
# 2         3.22     652.90          139       166    6.0       4     4.50
# 3         3.39     717.30          139       161    7.0       4     4.10
# 4         2.11     760.40          126       152    9.0       4     5.00
# ..         ...        ...          ...       ...    ...     ...      ...
# 151       2.57     760.00          159       188    7.0       6     4.72
# 152       2.95     840.00          128       185    8.0       6     5.93
# 153       1.49     870.00          136       177   10.0       6     5.97
# 154       0.74     890.13          136       174   11.0       6     5.41
# 155       0.17     703.00          148       143   15.0       6     4.34
#
#      Elec.Aff
# 0         7.6
# 1        50.6
# 2        64.3
# 3       -50.0
# 4        63.7
# ..        ...
# 151      14.5
# 152     106.1
# 153     205.3
# 154     222.8
# 155      91.2
#
# [156 rows x 30 columns]

# %% [markdown]
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(25,25))
# cor = df3.corr()
# G=sns.heatmap(cor,annot=True,cmap="RdYlBu")
# plt.show()

# %% [markdown]
# PCA_df = pd.read_csv('PCA_add.csv')
# PCA_df

# %% [markdown]
# combined_df = pd.concat([df3, PCA_df], axis=1)
# df4 = combined_df

# %% [markdown]
# df4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#plt.figure(figsize=(25,25))
#cor = df4.corr()
#G=sns.heatmap(cor,annot=True,cmap="RdYlBu")
#lt.show()

# %%
X = df3
y = df['CO_B.E']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=0)

X_train.shape, X_test.shape
# Out:
# ((109, 30), (47, 30))

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score
print("r2 on test data is",   r2_score(y_test, y_predict))
# Out:
# r2 on test data is 0.9702947106763663

# %%
print("RMSE:"+str(np.sqrt(mean_squared_error(y_test, y_predict))))
# Out:
# RMSE:0.08200909405694341

# %%
plt.scatter(y_test, y_predict)
plt.plot([-2.5,0.5], [-2.5,0.5],)

# %%
df_pred = pd.read_csv('Cu_based_bimet_CO_Binding.csv')
df_pred
# Out:
#     Element  M-At No.  M-At wt.  M-Density  M-M.P  M-B.P  M-Enth.fus  \
# 0   Cu3M-Sc        29    63.546       8.96   1357   2835        13.1
# 1   Cu3M-Ti        29    63.546       8.96   1357   2835        13.1
# 2    Cu3M-V        29    63.546       8.96   1357   2835        13.1
# 3   Cu3M-Cr        29    63.546       8.96   1357   2835        13.1
# 4   Cu3M-Mn        29    63.546       8.96   1357   2835        13.1
# 5   Cu3M-Co        29    63.546       8.96   1357   2835        13.1
# 6   Cu3M-Ni        29    63.546       8.96   1357   2835        13.1
# 7   Cu3M-Zn        29    63.546       8.96   1357   2835        13.1
# 8   Cu3M-Ga        29    63.546       8.96   1357   2835        13.1
# 9    Cu3M-Y        29    63.546       8.96   1357   2835        13.1
# 10  Cu3M-Zr        29    63.546       8.96   1357   2835        13.1
# 11  Cu3M-Nb        29    63.546       8.96   1357   2835        13.1
# 12  Cu3M-Mo        29    63.546       8.96   1357   2835        13.1
# 13  Cu3M-Ru        29    63.546       8.96   1357   2835        13.1
# 14  Cu3M-Rh        29    63.546       8.96   1357   2835        13.1
# 15  Cu3M-Pd        29    63.546       8.96   1357   2835        13.1
# 16  Cu3M-Ag        29    63.546       8.96   1357   2835        13.1
# 17  Cu3M-Sn        29    63.546       8.96   1357   2835        13.1
# 18  Cu3M-Ta        29    63.546       8.96   1357   2835        13.1
# 19  Cu3M-Re        29    63.546       8.96   1357   2835        13.1
# 20  Cu3M-Os        29    63.546       8.96   1357   2835        13.1
# 21  Cu3M-Ir        29    63.546       8.96   1357   2835        13.1
# 22  Cu3M-Pt        29    63.546       8.96   1357   2835        13.1
# 23  Cu3M-Au        29    63.546       8.96   1357   2835        13.1
#
#     M-Enth.atom  M-Enth.vap  M-Sp.ht Cap  ...  Elec.-ve  Surface.E  1st Ion E  \
# 0           338         300        384.4  ...      1.36       1.20     633.10
# 1           338         300        384.4  ...      1.54       1.93     658.80
# 2           338         300        384.4  ...      1.63       2.38     650.90
# 3           338         300        384.4  ...      1.66       3.22     652.90
# 4           338         300        384.4  ...      1.55       3.39     717.30
# 5           338         300        384.4  ...      1.88       2.11     760.40
# 6           338         300        384.4  ...      1.91       1.92     737.10
# 7           338         300        384.4  ...      1.65       0.33     906.40
# 8           338         300        384.4  ...      1.81       0.48     578.80
# 9           338         300        384.4  ...      1.22       1.00     600.00
# 10          338         300        384.4  ...      1.33       1.60     640.10
# 11          338         300        384.4  ...      1.60       2.06     652.10
# 12          338         300        384.4  ...      2.16       2.78     684.30
# 13          338         300        384.4  ...      2.20       2.60     710.20
# 14          338         300        384.4  ...      2.28       1.98     719.70
# 15          338         300        384.4  ...      2.20       1.36     804.40
# 16          338         300        384.4  ...      1.93       0.76     731.00
# 17          338         300        384.4  ...      1.96       0.54     708.60
# 18          338         300        384.4  ...      1.50       2.34     761.00
# 19          338         300        384.4  ...      1.90       2.57     760.00
# 20          338         300        384.4  ...      2.20       2.95     840.00
# 21          338         300        384.4  ...      2.20       2.36     880.00
# 22          338         300        384.4  ...      2.28       1.49     870.00
# 23          338         300        384.4  ...      2.54       0.74     890.13
#
#     cova .radii  At.radii  Group  Period  Work F.  Elec.Aff  CO_B.E
# 0           170       184      3       4    3.500      18.1     NaN
# 1           160       176      4       4    4.330       7.6     NaN
# 2           153       171      5       4    4.300      50.6     NaN
# 3           139       166      6       4    4.500      64.3     NaN
# 4           139       161      7       4    4.100     -50.0     NaN
# 5           126       152      9       4    5.000      63.7     NaN
# 6           121       149     10       4    5.240     112.0     NaN
# 7           122       142     12       4    3.630     -58.0     NaN
# 8           122       136     13       4    4.320      28.9     NaN
# 9           190       212      3       5    3.183      29.6     NaN
# 10          175       206      4       5    4.050      41.1     NaN
# 11          164       198      5       5    4.360      86.1     NaN
# 12          154       190      6       5    4.520      71.9     NaN
# 13          126       178      8       5    4.650     101.3     NaN
# 14          135       173      9       5    5.200     109.7     NaN
# 15          131       169     10       5    5.470      53.7     NaN
# 16          145       165     11       5    4.630     125.6     NaN
# 17          139       145     14       5    4.420     107.3     NaN
# 18          170       200      5       6    4.000      31.0     NaN
# 19          159       188      7       6    4.720      14.5     NaN
# 20          128       185      8       6    5.930     106.1     NaN
# 21          137       180      9       6    5.760     151.0     NaN
# 22          136       177     10       6    5.970     205.3     NaN
# 23          136       174     11       6    5.410     222.8     NaN
#
# [24 rows x 38 columns]

# %%
x = df_pred.drop(labels=["Element","CO_B.E","M-Enth.fus", "M-Enth.vap","Enth.fus","Enth.vap","M-Enth.atom","Enth.atom"], axis=1)
x
# Out:
#     M-At No.  M-At wt.  M-Density  M-M.P  M-B.P  M-Sp.ht Cap  M-Elec.-ve  \
# 0         29    63.546       8.96   1357   2835        384.4         1.9
# 1         29    63.546       8.96   1357   2835        384.4         1.9
# 2         29    63.546       8.96   1357   2835        384.4         1.9
# 3         29    63.546       8.96   1357   2835        384.4         1.9
# 4         29    63.546       8.96   1357   2835        384.4         1.9
# 5         29    63.546       8.96   1357   2835        384.4         1.9
# 6         29    63.546       8.96   1357   2835        384.4         1.9
# 7         29    63.546       8.96   1357   2835        384.4         1.9
# 8         29    63.546       8.96   1357   2835        384.4         1.9
# 9         29    63.546       8.96   1357   2835        384.4         1.9
# 10        29    63.546       8.96   1357   2835        384.4         1.9
# 11        29    63.546       8.96   1357   2835        384.4         1.9
# 12        29    63.546       8.96   1357   2835        384.4         1.9
# 13        29    63.546       8.96   1357   2835        384.4         1.9
# 14        29    63.546       8.96   1357   2835        384.4         1.9
# 15        29    63.546       8.96   1357   2835        384.4         1.9
# 16        29    63.546       8.96   1357   2835        384.4         1.9
# 17        29    63.546       8.96   1357   2835        384.4         1.9
# 18        29    63.546       8.96   1357   2835        384.4         1.9
# 19        29    63.546       8.96   1357   2835        384.4         1.9
# 20        29    63.546       8.96   1357   2835        384.4         1.9
# 21        29    63.546       8.96   1357   2835        384.4         1.9
# 22        29    63.546       8.96   1357   2835        384.4         1.9
# 23        29    63.546       8.96   1357   2835        384.4         1.9
#
#     M-Surface.E  M-1st Ion E  M-cova .radii  ...  Sp.ht Cap  Elec.-ve  \
# 0          1.34        745.5            132  ...      567.0      1.36
# 1          1.34        745.5            132  ...      520.0      1.54
# 2          1.34        745.5            132  ...      489.0      1.63
# 3          1.34        745.5            132  ...      448.0      1.66
# 4          1.34        745.5            132  ...      479.0      1.55
# 5          1.34        745.5            132  ...      421.0      1.88
# 6          1.34        745.5            132  ...      445.0      1.91
# 7          1.34        745.5            132  ...      388.0      1.65
# 8          1.34        745.5            132  ...      371.0      1.81
# 9          1.34        745.5            132  ...      298.0      1.22
# 10         1.34        745.5            132  ...      278.0      1.33
# 11         1.34        745.5            132  ...      265.0      1.60
# 12         1.34        745.5            132  ...      251.0      2.16
# 13         1.34        745.5            132  ...      238.0      2.20
# 14         1.34        745.5            132  ...      240.0      2.28
# 15         1.34        745.5            132  ...      240.0      2.20
# 16         1.34        745.5            132  ...      235.0      1.93
# 17         1.34        745.5            132  ...      217.0      1.96
# 18         1.34        745.5            132  ...      140.0      1.50
# 19         1.34        745.5            132  ...      137.0      1.90
# 20         1.34        745.5            132  ...      130.0      2.20
# 21         1.34        745.5            132  ...      131.0      2.20
# 22         1.34        745.5            132  ...      133.0      2.28
# 23         1.34        745.5            132  ...      129.1      2.54
#
#     Surface.E  1st Ion E  cova .radii  At.radii  Group  Period  Work F.  \
# 0        1.20     633.10          170       184      3       4    3.500
# 1        1.93     658.80          160       176      4       4    4.330
# 2        2.38     650.90          153       171      5       4    4.300
# 3        3.22     652.90          139       166      6       4    4.500
# 4        3.39     717.30          139       161      7       4    4.100
# 5        2.11     760.40          126       152      9       4    5.000
# 6        1.92     737.10          121       149     10       4    5.240
# 7        0.33     906.40          122       142     12       4    3.630
# 8        0.48     578.80          122       136     13       4    4.320
# 9        1.00     600.00          190       212      3       5    3.183
# 10       1.60     640.10          175       206      4       5    4.050
# 11       2.06     652.10          164       198      5       5    4.360
# 12       2.78     684.30          154       190      6       5    4.520
# 13       2.60     710.20          126       178      8       5    4.650
# 14       1.98     719.70          135       173      9       5    5.200
# 15       1.36     804.40          131       169     10       5    5.470
# 16       0.76     731.00          145       165     11       5    4.630
# 17       0.54     708.60          139       145     14       5    4.420
# 18       2.34     761.00          170       200      5       6    4.000
# 19       2.57     760.00          159       188      7       6    4.720
# 20       2.95     840.00          128       185      8       6    5.930
# 21       2.36     880.00          137       180      9       6    5.760
# 22       1.49     870.00          136       177     10       6    5.970
# 23       0.74     890.13          136       174     11       6    5.410
#
#     Elec.Aff
# 0       18.1
# 1        7.6
# 2       50.6
# 3       64.3
# 4      -50.0
# 5       63.7
# 6      112.0
# 7      -58.0
# 8       28.9
# 9       29.6
# 10      41.1
# 11      86.1
# 12      71.9
# 13     101.3
# 14     109.7
# 15      53.7
# 16     125.6
# 17     107.3
# 18      31.0
# 19      14.5
# 20     106.1
# 21     151.0
# 22     205.3
# 23     222.8
#
# [24 rows x 30 columns]

# %% [markdown]
# PCA_df_Cu_pred = pd.read_csv('PCA_add_Cu_Pred.csv')
# PCA_df_Cu_pred

# %% [markdown]
# combined_df_Cu_pred = pd.concat([x, PCA_df_Cu_pred], axis=1)
# df_Cu_pred = combined_df_Cu_pred
# df_Cu_pred

# %%
model.predict(x)
# Out:
# array([-0.5597417 , -0.27655712, -0.28420627, -0.3413    , -0.368865  ,
#        -0.3629183 , -0.42375222, -0.35245734, -0.4824315 , -0.18251206,
#        -0.05220822, -0.18783873, -0.32452708, -0.30552435, -0.3315994 ,
#        -0.44329837, -0.43333125, -0.29186085, -0.08826344, -0.4069565 ,
#        -0.40530595, -0.32678273, -0.38424173, -0.376215  ], dtype=float32)

# %%
H_params = model.get_params()
H_params
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': 0.5,
#  'booster': 'gbtree',
#  'callbacks': None,
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'gamma': 0,
#  'gpu_id': -1,
#  'grow_policy': 'depthwise',
#  'importance_type': None,
#  'interaction_constraints': '',
#  'learning_rate': 0.300000012,
#  'max_bin': 256,
#  'max_cat_to_onehot': 4,
#  'max_delta_step': 0,
#  'max_depth': 6,
#  'max_leaves': 0,
#  'min_child_weight': 1,
#  'missing': nan,
#  'monotone_constraints': '()',
#  'n_estimators': 100,
#  'n_jobs': 0,
#  'num_parallel_tree': 1,
#  'predictor': 'auto',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'sampling_method': 'uniform',
#  'scale_pos_weight': 1,
#  'subsample': 1,
#  'tree_method': 'exact',
#  'validate_parameters': 1,
#  'verbosity': None}

# %%
p = model.predict(x)
p = pd.DataFrame(p)
p
# Out:
#            0
# 0  -0.559742
# 1  -0.276557
# 2  -0.284206
# 3  -0.341300
# 4  -0.368865
# 5  -0.362918
# 6  -0.423752
# 7  -0.352457
# 8  -0.482432
# 9  -0.182512
# 10 -0.052208
# 11 -0.187839
# 12 -0.324527
# 13 -0.305524
# 14 -0.331599
# 15 -0.443298
# 16 -0.433331
# 17 -0.291861
# 18 -0.088263
# 19 -0.406956
# 20 -0.405306
# 21 -0.326783
# 22 -0.384242
# 23 -0.376215

# %%
output_file_CO = 'output_data_CO.xlsx'
p.to_excel(output_file_CO, index=False)
print(f"Data frame converted and saved to '{output_file_CO}'.")
# Out:
# Data frame converted and saved to 'output_data_CO.xlsx'.

# %%
print(model.feature_importances_)
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='bar')
plt.show()
# Out:
# [1.00895083e-02 0.00000000e+00 1.22339167e-02 3.71662021e-01
#  0.00000000e+00 0.00000000e+00 7.16895040e-04 5.54572403e-01
#  1.27049439e-04 3.59800557e-04 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.55747601e-04 3.13604716e-04 6.29847171e-04
#  1.53261688e-04 3.84497078e-04 8.75287876e-03 1.18974186e-02
#  2.68303003e-04 4.10250621e-03 2.98539922e-03 1.20037328e-03
#  1.01360595e-02 5.74553758e-03 1.85902347e-03 0.00000000e+00
#  6.48682180e-04 5.05278527e-04]

# %%
from scipy.stats import uniform, randint
from sklearn.linear_model import Lasso
from scipy.stats.qmc import Sobol

# %%
from sklearn.model_selection import RandomizedSearchCV , GridSearchCV
import xgboost as xgb

params = { 'max_depth': np.arange(3,15,1),                     #13
           'learning_rate': np.arange(0.01,0.1, 0.01),      #0.325
           'subsample': np.arange(0.7, 1, 0.01), 
           'min_child_weight': np.arange(3,15, 1),
           #'colsample_bytree': np.arange(0.99, 1, 0.01),        
           #'colsample_bylevel': np.arange(0.99, 1, 0.01),       
           'n_estimators': np.arange(200,1000,25),                #450
           #'reg_alpha': uniform(1,3),                     #0.8612124738904751
           #'reg_lambda': uniform(1,10),                      #115.01455430429743  
         }
sobol_sequence = Sobol(1)
lasso = Lasso()
# number of times random search is run
n = 50                                             # n=20    #n_iter=50  #cv=10

# %%
xgbr = xgb.XGBRegressor(seed=20)
average = np.array([0]*30, dtype=np.float64)
feature_importances = []

nth_run = 1
rmse_values_test = []
rmse_values_train = []
avg = 0

for i in range(n):   
    clf = RandomizedSearchCV(estimator=xgbr,
                             param_distributions=params,
                             scoring='neg_mean_squared_error',
                             n_iter=100,cv=10,random_state=np.random.RandomState(int(sobol_sequence.random(1)[0] * 2**31)),
                             verbose=1)
    clf.fit(X_train,y_train)
    
    print(f"Run {i + 1}: Best Estimator: {clf.best_estimator_}")
    
    if (i + 1) % nth_run == 0:
        # Predictions on test set
        y_pred_test = clf.predict(X_test)
        mse_test = mean_squared_error(y_test, y_pred_test)
        rmse_test = np.sqrt(mse_test)
        rmse_values_test.append(rmse_test)
        
        # Predictions on training set
        y_pred_train = clf.predict(X_train)
        mse_train = mean_squared_error(y_train, y_pred_train)
        rmse_train = np.sqrt(mse_train)
        rmse_values_train.append(rmse_train)

        print(f"RMSE for every {nth_run}th run - Training: {rmse_train}, Test: {rmse_test}")
        nth_run += 1
    
    average += clf.best_estimator_.feature_importances_
    feature_importances.append(clf.best_estimator_.feature_importances_)
average = average/n
avg = avg/n
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 1: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=3,
#              missing=nan, monotone_constraints='()', n_estimators=950, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 1th run - Training: 0.0010583163515463755, Test: 0.08591463079554353
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 2: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=975, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 2th run - Training: 0.0009437803253885276, Test: 0.09371420348345817
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 3: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.06999999999999999, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=14, max_leaves=0,
#              min_child_weight=7, missing=nan, monotone_constraints='()',
#              n_estimators=550, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 3th run - Training: 0.0023794245280546705, Test: 0.08870506308597652
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 4: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=5, max_leaves=0, min_child_weight=5,
#              missing=nan, monotone_constraints='()', n_estimators=350, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 4th run - Training: 0.014711483648492308, Test: 0.09170940586859022
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 5: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=875, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 5th run - Training: 0.0013782894283691156, Test: 0.09240478265113433
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 6: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=8, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=850, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 6th run - Training: 0.0057071346434421025, Test: 0.0915501651806574
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 7: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.060000000000000005, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=14, max_leaves=0,
#              min_child_weight=7, missing=nan, monotone_constraints='()',
#              n_estimators=475, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 7th run - Training: 0.0047806420956597205, Test: 0.08516618464346438
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 8: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=5,
#              missing=nan, monotone_constraints='()', n_estimators=525, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 8th run - Training: 0.008343130964522483, Test: 0.09313472204498509
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 9: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.02, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=3,
#              missing=nan, monotone_constraints='()', n_estimators=725, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 9th run - Training: 0.00705945442663862, Test: 0.08667195790056162
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 10: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=13, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=325, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 10th run - Training: 0.024490678867976092, Test: 0.09852208852687226
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 11: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=800, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 11th run - Training: 0.0010387546608149427, Test: 0.09516027186248477
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 12: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=3,
#              missing=nan, monotone_constraints='()', n_estimators=450, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 12th run - Training: 0.0008535047644297194, Test: 0.08980674859782267
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 13: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=4, max_leaves=0, min_child_weight=3,
#              missing=nan, monotone_constraints='()', n_estimators=250, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 13th run - Training: 0.02316767623680839, Test: 0.09070801154400004
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 14: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.06999999999999999, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=7, max_leaves=0,
#              min_child_weight=7, missing=nan, monotone_constraints='()',
#              n_estimators=300, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 14th run - Training: 0.010664873465410368, Test: 0.09253524517481197
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 15: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.09, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=700, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 15th run - Training: 0.0007115434998579536, Test: 0.09631078209844647
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 16: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.02, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=5,
#              missing=nan, monotone_constraints='()', n_estimators=950, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 16th run - Training: 0.005930235980307082, Test: 0.0894483226633073
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 17: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=8, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=925, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 17th run - Training: 0.0008524633418734336, Test: 0.09156787359074864
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 18: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=7,
#              missing=nan, monotone_constraints='()', n_estimators=775, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 18th run - Training: 0.009368015797909789, Test: 0.08832876705152018
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 19: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=5, max_leaves=0, min_child_weight=7,
#              missing=nan, monotone_constraints='()', n_estimators=950, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 19th run - Training: 0.006546322165468083, Test: 0.09047666664091886
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 20: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=975, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 20th run - Training: 0.001255716192745432, Test: 0.08902010139372761
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 21: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=5,
#              missing=nan, monotone_constraints='()', n_estimators=775, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 21th run - Training: 0.0024797391981967263, Test: 0.09184647621281133
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 22: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=7,
#              missing=nan, monotone_constraints='()', n_estimators=825, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 22th run - Training: 0.0026164495828859577, Test: 0.08624237259339976
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 23: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=550, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 23th run - Training: 0.009254650263923837, Test: 0.08977428060712586
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 24: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.06999999999999999, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=13, max_leaves=0,
#              min_child_weight=7, missing=nan, monotone_constraints='()',
#              n_estimators=925, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 24th run - Training: 0.0013051117237379963, Test: 0.08786565277423712
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 25: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.060000000000000005, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=6, max_leaves=0,
#              min_child_weight=7, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 25th run - Training: 0.0054022674499668326, Test: 0.08874412679087558
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 26: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=13, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=375, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 26th run - Training: 0.010032813476611108, Test: 0.09155629381661352
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 27: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.06999999999999999, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=7, max_leaves=0,
#              min_child_weight=5, missing=nan, monotone_constraints='()',
#              n_estimators=675, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 27th run - Training: 0.0012238650171324582, Test: 0.09235363277637101
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 28: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=7,
#              missing=nan, monotone_constraints='()', n_estimators=725, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 28th run - Training: 0.010013324835242103, Test: 0.08787158500043132
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 29: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.03, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=975, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 29th run - Training: 0.0011110991720438075, Test: 0.08995434648757206
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 30: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=750, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 30th run - Training: 0.001372282889343719, Test: 0.09289428028140397
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 31: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=7,
#              missing=nan, monotone_constraints='()', n_estimators=825, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 31th run - Training: 0.001328362837809522, Test: 0.08705816076270509
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 32: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.06999999999999999, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=12, max_leaves=0,
#              min_child_weight=5, missing=nan, monotone_constraints='()',
#              n_estimators=975, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 32th run - Training: 0.0011615505161179942, Test: 0.09370458526232257
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 33: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.09, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=5,
#              missing=nan, monotone_constraints='()', n_estimators=550, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 33th run - Training: 0.0010268577971594274, Test: 0.09081112566531584
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 34: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=7,
#              missing=nan, monotone_constraints='()', n_estimators=550, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 34th run - Training: 0.0018424154497077272, Test: 0.08635481299111306
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 35: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=7,
#              missing=nan, monotone_constraints='()', n_estimators=450, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 35th run - Training: 0.009015689056105825, Test: 0.08955769582372719
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 36: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.06999999999999999, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=8, max_leaves=0,
#              min_child_weight=7, missing=nan, monotone_constraints='()',
#              n_estimators=400, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 36th run - Training: 0.0058239833760130545, Test: 0.09024589195757574
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 37: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=5, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=425, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 37th run - Training: 0.009910790656369796, Test: 0.09324457670941973
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 38: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.06999999999999999, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=11, max_leaves=0,
#              min_child_weight=7, missing=nan, monotone_constraints='()',
#              n_estimators=950, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 38th run - Training: 0.0014549217474901523, Test: 0.0855514973743174
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 39: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=3,
#              missing=nan, monotone_constraints='()', n_estimators=575, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 39th run - Training: 0.0011061398436833887, Test: 0.08906948300364993
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 40: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.060000000000000005, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=6, max_leaves=0,
#              min_child_weight=6, missing=nan, monotone_constraints='()',
#              n_estimators=725, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=20, reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 40th run - Training: 0.0026628166977949222, Test: 0.09235306324503274
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 41: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.02, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=3,
#              missing=nan, monotone_constraints='()', n_estimators=800, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 41th run - Training: 0.004705727116566079, Test: 0.08466782876254261
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 42: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=13, max_leaves=0, min_child_weight=5,
#              missing=nan, monotone_constraints='()', n_estimators=375, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 42th run - Training: 0.010404122666654006, Test: 0.09292846117647031
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 43: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=9, max_leaves=0, min_child_weight=3,
#              missing=nan, monotone_constraints='()', n_estimators=700, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 43th run - Training: 0.0013377236105152342, Test: 0.0852916992240589
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 44: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=475, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 44th run - Training: 0.004923777992585823, Test: 0.0938167943893566
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 45: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.02, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=3,
#              missing=nan, monotone_constraints='()', n_estimators=750, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 45th run - Training: 0.007240396638090246, Test: 0.08625019856362799
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 46: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=11, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=725, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 46th run - Training: 0.0010373707267277057, Test: 0.09248994392322296
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 47: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=14, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=775, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 47th run - Training: 0.0028780050111306393, Test: 0.08860074912509554
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 48: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=8, max_leaves=0, min_child_weight=7,
#              missing=nan, monotone_constraints='()', n_estimators=350, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 48th run - Training: 0.005069237398558422, Test: 0.08643395178467003
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 49: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=13, max_leaves=0, min_child_weight=5,
#              missing=nan, monotone_constraints='()', n_estimators=275, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 49th run - Training: 0.018627892810941786, Test: 0.09528610695219943
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Run 50: Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.04, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=13, max_leaves=0, min_child_weight=6,
#              missing=nan, monotone_constraints='()', n_estimators=775, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=20,
#              reg_alpha=0, reg_lambda=1, ...)
# RMSE for every 50th run - Training: 0.007211292030207917, Test: 0.09361665749909358

# %%
np.min(rmse_values_test), np.max(rmse_values_test)
# Out:
# (0.08466782876254261, 0.09852208852687226)

# %%
np.min(rmse_values_train), np.max(rmse_values_train)
# Out:
# (0.0007115434998579536, 0.024490678867976092)

# %%
mean_rmse_test = np.mean(rmse_values_test)
print(f"Mean RMSE: {mean_rmse_test}")
# Out:
# Mean RMSE: 0.09034584652670782

# %%
mean_rmse_train = np.mean(rmse_values_train)
print(f"Mean RMSE: {mean_rmse_train}")
# Out:
# Mean RMSE: 0.005496442379500588

# %%
average
# Out:
# array([0.01211765, 0.        , 0.01039796, 0.43357745, 0.        ,
#        0.        , 0.00145283, 0.48161393, 0.00163165, 0.00211334,
#        0.        , 0.        , 0.        , 0.00252665, 0.00144611,
#        0.00115965, 0.00053883, 0.00097054, 0.00912981, 0.00569816,
#        0.00074467, 0.00783963, 0.00388075, 0.00126628, 0.0051193 ,
#        0.00560093, 0.00804734, 0.        , 0.00153377, 0.0015928 ])

# %%
avg
# Out:
# 0.0

# %%
plt.bar(x=range(30), height=np.mean(feature_importances, axis=0), yerr=np.std(feature_importances, axis=0))
plt.xticks(ticks = range(30),labels=X_train.columns, rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x20e3a9c3430>,
#   <matplotlib.axis.XTick at 0x20e3a9c3670>,
#   <matplotlib.axis.XTick at 0x20e3aa90970>,
#   <matplotlib.axis.XTick at 0x20e3ae54130>,
#   <matplotlib.axis.XTick at 0x20e3abf0cd0>,
#   <matplotlib.axis.XTick at 0x20e3add0100>,
#   <matplotlib.axis.XTick at 0x20e3a9bf910>,
#   <matplotlib.axis.XTick at 0x20e3aabee20>,
#   <matplotlib.axis.XTick at 0x20e3aa61700>,
#   <matplotlib.axis.XTick at 0x20e3aa78b80>,
#   <matplotlib.axis.XTick at 0x20e3aa854c0>,
#   <matplotlib.axis.XTick at 0x20e3aa61ee0>,
#   <matplotlib.axis.XTick at 0x20e3a9bfbb0>,
#   <matplotlib.axis.XTick at 0x20e3aa85070>,
#   <matplotlib.axis.XTick at 0x20e3aaa35e0>,
#   <matplotlib.axis.XTick at 0x20e3aaa34c0>,
#   <matplotlib.axis.XTick at 0x20e3aaacf10>,
#   <matplotlib.axis.XTick at 0x20e3aaac610>,
#   <matplotlib.axis.XTick at 0x20e3aaa3700>,
#   <matplotlib.axis.XTick at 0x20e3ae7fac0>,
#   <matplotlib.axis.XTick at 0x20e3aaac5b0>,
#   <matplotlib.axis.XTick at 0x20e3addaac0>,
#   <matplotlib.axis.XTick at 0x20e3addaf70>,
#   <matplotlib.axis.XTick at 0x20e3aa742e0>,
#   <matplotlib.axis.XTick at 0x20e3aa74f40>,
#   <matplotlib.axis.XTick at 0x20e3adda9d0>,
#   <matplotlib.axis.XTick at 0x20e3aadb6a0>,
#   <matplotlib.axis.XTick at 0x20e3ae63970>,
#   <matplotlib.axis.XTick at 0x20e3aa7ceb0>,
#   <matplotlib.axis.XTick at 0x20e3aa86640>],
#  [Text(0, 0, 'M-At No.'),
#   Text(1, 0, 'M-At wt.'),
#   Text(2, 0, 'M-Density'),
#   Text(3, 0, 'M-M.P'),
#   Text(4, 0, 'M-B.P'),
#   Text(5, 0, 'M-Sp.ht Cap'),
#   Text(6, 0, 'M-Elec.-ve'),
#   Text(7, 0, 'M-Surface.E'),
#   Text(8, 0, 'M-1st Ion E'),
#   Text(9, 0, 'M-cova .radii'),
#   Text(10, 0, 'M-At.radii'),
#   Text(11, 0, 'M-Group'),
#   Text(12, 0, 'M-Period'),
#   Text(13, 0, 'M-Work F.'),
#   Text(14, 0, 'M-Elec.Aff'),
#   Text(15, 0, 'At No.'),
#   Text(16, 0, 'At wt.'),
#   Text(17, 0, 'Density'),
#   Text(18, 0, 'M.P'),
#   Text(19, 0, 'B.P'),
#   Text(20, 0, 'Sp.ht Cap'),
#   Text(21, 0, 'Elec.-ve'),
#   Text(22, 0, 'Surface.E'),
#   Text(23, 0, '1st Ion E'),
#   Text(24, 0, 'cova .radii'),
#   Text(25, 0, 'At.radii'),
#   Text(26, 0, 'Group'),
#   Text(27, 0, 'Period'),
#   Text(28, 0, 'Work F.'),
#   Text(29, 0, 'Elec.Aff')])

# %%
len(clf.best_estimator_.feature_importances_)
[0]*24

print("Best parameters:", clf.best_params_)
# Out:
# Best parameters: {'subsample': 0.77, 'n_estimators': 775, 'min_child_weight': 6, 'max_depth': 13, 'learning_rate': 0.04}

# %%
print("neg-MSE:", clf.best_score_)
# Out:
# neg-MSE: -0.014491765021873165

# %%
y_pred = clf.best_estimator_.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

rmse
# Out:
# 0.09361665749909358

# %%
from sklearn.metrics import r2_score

# Add this snippet at the end of your code
y_pred_test = clf.best_estimator_.predict(X_test)
r2 = r2_score(y_test, y_pred_test)

print(f"Best R² score for the test set: {r2}")
# Out:
# Best R² score for the test set: 0.9612906374192425

# %%
y_predict = clf.best_estimator_.predict(X_test)

# %%
y_train_predict = clf.best_estimator_.predict(X_train)
plt.figure(figsize=(12, 8))
plt.scatter(y_train, y_train_predict, facecolors='black', edgecolors='black', s=10)
plt.scatter(y_test, y_predict, marker='s', edgecolors='red',facecolors='pink' ,s=15)
plt.plot([-3.0,1.5], [-3.0,1.5],)
plt.grid(True)
plt.xlabel('DFT-calculated')
plt.ylabel('Predicted')
plt.title('(d) - Train/Test = 0.70/0.30 ')

plt.show
plt.savefig('DFT vs predicted(xGBR) - test_size_0.30_mcw_md.jpg',dpi = 500)

# %%
y_train_predict = clf.best_estimator_.predict(X_train)
plt.figure(figsize=(12, 8),dpi=400)
plt.scatter(y_train, y_train_predict, facecolors='black', edgecolors='black', s=30)
plt.scatter(y_test, y_predict, marker='s', edgecolors='red',facecolors='pink' ,s=35)
plt.plot([-2.5,2], [-2.5,2],)
plt.grid(False)
plt.xlabel('DFT-calculated', fontsize=25)
plt.ylabel('Predicted', fontsize=25)
plt.title('(a) - Train/Test = 0.70/0.30 ', fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.show
plt.savefig('DFT vs predicted(xGBR) - test_size_0.30.jpg',dpi = 500)

# %%
t = clf.best_estimator_.predict(x)
t = pd.DataFrame(t)
t
# Out:
#            0
# 0  -0.495955
# 1  -0.199722
# 2  -0.106305
# 3  -0.313694
# 4  -0.254362
# 5  -0.160724
# 6  -0.245858
# 7  -0.242100
# 8  -0.273751
# 9  -0.343257
# 10 -0.286223
# 11 -0.090481
# 12 -0.122933
# 13 -0.133648
# 14 -0.167910
# 15 -0.231361
# 16 -0.295031
# 17 -0.156433
# 18 -0.019042
# 19 -0.163158
# 20 -0.163310
# 21 -0.143689
# 22 -0.193091
# 23 -0.234951

# %%
output_file_CO_HT = 'output_data_CO_xGBR(0.30)_mcw_md.xlsx'
t.to_excel(output_file_CO_HT, index=False)
print(f"Data frame converted and saved to '{output_file_CO_HT}'.")
# Out:
# Data frame converted and saved to 'output_data_CO_xGBR(0.30)_mcw_md.xlsx'.

# %%
clf.best_estimator_.feature_importances_
plt.figure(figsize=(12, 8))
feat_importances = pd.Series(clf.best_estimator_.feature_importances_, index=X.columns)
feat_importances.nlargest(15).plot(kind='bar')
plt.xlabel('Features')
plt.ylabel('Importance - scale (0-1)')
plt.show()

plt.savefig('Feature_Importance_xGBR_(0.30)_mcw_md.jpg',dpi = 500)

# %%
# Assuming X is your feature matrix and clf is your trained classifier
# Replace 'dog' and 'cat' with the actual feature names you want to exclude
features_to_exclude = ['M-Surface.E', 'M-M.P']

# Get feature importances
importances = clf.best_estimator_.feature_importances_

# Create a DataFrame with feature importances
feat_importances = pd.Series(importances, index=X.columns)

# Drop the specified features
feat_importances = feat_importances.drop(features_to_exclude, errors='ignore')

# Plot the feature importances
plt.figure(figsize=(12, 8))
feat_importances.nlargest(29).plot(kind='bar')
plt.xlabel('Features')
plt.ylabel('Importance - scale (0-1)')
plt.show()

# Save the plot
plt.savefig('Feature_Importance_xGBR_(0.30)_Remaining_mcw_md.jpg', dpi=500)

# %%
avg=np.mean(feature_importances, axis=0)
feat_importances = pd.Series(avg, index=X.columns)
feat_importances.nlargest(10).plot(kind='bar')
plt.show()

# %%
med=np.median(feature_importances, axis=0)
feat_importances = pd.Series(med, index=X.columns)
feat_importances.nlargest(10).plot(kind='bar')
plt.show()

# %%
std=np.std(feature_importances, axis=0)
plt.figure(figsize=(12, 8))
feat_importances = pd.Series(std, index=X.columns)
feat_importances.nlargest(10).plot(kind='bar')
plt.xlabel('Features')
plt.ylabel('Standard Deviation')
plt.show()
plt.savefig('Standard_deviation_xGBR_(0.30)_mcw_md.jpg', dpi=500)
