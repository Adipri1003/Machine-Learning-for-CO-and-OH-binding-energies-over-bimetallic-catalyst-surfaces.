# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('N.csv')
df
# Out:
#     Elements  M1  M2  M1%  M2%  AN-1    AM-1  G-1  P-1   R-1  ...  \
# 0      Ag3Cd  Ag  Cd    3    1    47  107.87   11    5  1.65  ...
# 1      Ag3Ga  Ag  Ga    3    1    47  107.87   11    5  1.65  ...
# 2      Ag3In  Ag  In    3    1    47  107.87   11    5  1.65  ...
# 3      Ag3La  Ag  La    3    1    47  107.87   11    5  1.65  ...
# 4      Ag3Pd  Ag  Pd    3    1    47  107.87   11    5  1.65  ...
# ..       ...  ..  ..  ...  ...   ...     ...  ...  ...   ...  ...
# 211    Sn3Sn  Sn  Sn    3    1    50  118.71   14    5  1.45  ...
# 212    Ti3Ti  Ti  Ti    3    1    22   47.87    4    4  1.76  ...
# 213    Zn3Zn  Zn  Zn    3    1    30   65.38   12    4  1.42  ...
# 214    Pt3Tl  Pt  Tl    3    1    78  195.08   10    6  1.77  ...
# 215    Tl3Tl  Tl  Tl    3    1    81  204.38   13    6  1.56  ...
#
#      Unnamed: 34  Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 211          NaN          NaN          NaN          NaN          NaN
# 212          NaN          NaN          NaN          NaN          NaN
# 213          NaN          NaN          NaN          NaN          NaN
# 214          NaN          NaN          NaN          NaN          NaN
# 215          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 39  Unnamed: 40  Unnamed: 41  Unnamed: 42  Unnamed: 43
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 211          NaN          NaN          NaN          NaN          NaN
# 212          NaN          NaN          NaN          NaN          NaN
# 213          NaN          NaN          NaN          NaN          NaN
# 214          NaN          NaN          NaN          NaN          NaN
# 215          NaN          NaN          NaN          NaN          NaN
#
# [216 rows x 44 columns]

# %%
df2=df.iloc[:,5:29]
df2
# Out:
#      AN-1    AM-1  G-1  P-1   R-1  EN-1  m.p.-1  b.p.-1  Hfus-1  density-1  \
# 0      47  107.87   11    5  1.65  1.42    1235    2435    11.3      10.50
# 1      47  107.87   11    5  1.65  1.42    1235    2435    11.3      10.50
# 2      47  107.87   11    5  1.65  1.42    1235    2435    11.3      10.50
# 3      47  107.87   11    5  1.65  1.42    1235    2435    11.3      10.50
# 4      47  107.87   11    5  1.65  1.42    1235    2435    11.3      10.50
# ..    ...     ...  ...  ...   ...   ...     ...     ...     ...        ...
# 211    50  118.71   14    5  1.45  1.72     505    2875     7.2       7.26
# 212    22   47.87    4    4  1.76  1.32    1941    3560    14.2       4.51
# 213    30   65.38   12    4  1.42  1.66     693    1180     7.1       7.14
# 214    78  195.08   10    6  1.77  1.44    2042    4098    22.2      21.50
# 215    81  204.38   13    6  1.56  1.44     577    1746     4.1      11.80
#
#      ...  G-2  P-2   R-2  EN-2  m.p.-2  b.p.-2  Hfus-2  density-2  IE-2  \
# 0    ...   12    5  1.61  1.46     594    1040     6.2       8.69  8.99
# 1    ...   13    4  1.36  1.82     303    2477     5.6       5.91  6.00
# 2    ...   13    5  1.56  1.49     430    2345     3.3       7.31  5.79
# 3    ...    4    6  1.95  1.08    1191    3737     6.2       6.15  5.58
# 4    ...   10    5  1.69  1.35    1828    3236    16.7      12.00  8.34
# ..   ...  ...  ...   ...   ...     ...     ...     ...        ...   ...
# 211  ...   14    5  1.45  1.72     505    2875     7.2       7.26  7.35
# 212  ...    4    4  1.76  1.32    1941    3560    14.2       4.51  6.83
# 213  ...   12    4  1.42  1.66     693    1180     7.1       7.14  9.39
# 214  ...   13    6  1.56  1.44     577    1746     4.1      11.80  6.11
# 215  ...   13    6  1.56  1.44     577    1746     4.1      11.80  6.11
#
#      surface energy-2
# 0                0.20
# 1                0.48
# 2                0.30
# 3                0.70
# 4                1.34
# ..                ...
# 211              0.54
# 212              1.93
# 213              0.35
# 214              0.22
# 215              0.22
#
# [216 rows x 24 columns]

# %%
print(df2.columns.tolist())
# Out:
# ['AN-1', 'AM-1', 'G-1', 'P-1', 'R-1', 'EN-1', 'm.p.-1', 'b.p.-1', 'Hfus-1', 'density-1', 'IE-1', 'surface energy-1', 'AN-2', 'AM-2', 'G-2', 'P-2', 'R-2', 'EN-2', 'm.p.-2', 'b.p.-2', 'Hfus-2', 'density-2', 'IE-2', 'surface energy-2']

# %%
X= df2
y= df['EN (eV)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)

X_train.shape, X_test.shape
# Out:
# ((151, 24), (65, 24))

# %% [markdown]
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(30,30))
# cor = df2.corr()
# G=sns.heatmap(cor,annot=True,cmap="RdYlBu")
# plt.show()

# %%
df2
# Out:
#      AN-1    AM-1  G-1  P-1   R-1  EN-1  m.p.-1  b.p.-1  Hfus-1  density-1  \
# 0      47  107.87   11    5  1.65  1.42    1235    2435    11.3      10.50
# 1      47  107.87   11    5  1.65  1.42    1235    2435    11.3      10.50
# 2      47  107.87   11    5  1.65  1.42    1235    2435    11.3      10.50
# 3      47  107.87   11    5  1.65  1.42    1235    2435    11.3      10.50
# 4      47  107.87   11    5  1.65  1.42    1235    2435    11.3      10.50
# ..    ...     ...  ...  ...   ...   ...     ...     ...     ...        ...
# 211    50  118.71   14    5  1.45  1.72     505    2875     7.2       7.26
# 212    22   47.87    4    4  1.76  1.32    1941    3560    14.2       4.51
# 213    30   65.38   12    4  1.42  1.66     693    1180     7.1       7.14
# 214    78  195.08   10    6  1.77  1.44    2042    4098    22.2      21.50
# 215    81  204.38   13    6  1.56  1.44     577    1746     4.1      11.80
#
#      ...  G-2  P-2   R-2  EN-2  m.p.-2  b.p.-2  Hfus-2  density-2  IE-2  \
# 0    ...   12    5  1.61  1.46     594    1040     6.2       8.69  8.99
# 1    ...   13    4  1.36  1.82     303    2477     5.6       5.91  6.00
# 2    ...   13    5  1.56  1.49     430    2345     3.3       7.31  5.79
# 3    ...    4    6  1.95  1.08    1191    3737     6.2       6.15  5.58
# 4    ...   10    5  1.69  1.35    1828    3236    16.7      12.00  8.34
# ..   ...  ...  ...   ...   ...     ...     ...     ...        ...   ...
# 211  ...   14    5  1.45  1.72     505    2875     7.2       7.26  7.35
# 212  ...    4    4  1.76  1.32    1941    3560    14.2       4.51  6.83
# 213  ...   12    4  1.42  1.66     693    1180     7.1       7.14  9.39
# 214  ...   13    6  1.56  1.44     577    1746     4.1      11.80  6.11
# 215  ...   13    6  1.56  1.44     577    1746     4.1      11.80  6.11
#
#      surface energy-2
# 0                0.20
# 1                0.48
# 2                0.30
# 3                0.70
# 4                1.34
# ..                ...
# 211              0.54
# 212              1.93
# 213              0.35
# 214              0.22
# 215              0.22
#
# [216 rows x 24 columns]

# %%
X = df2
y = df['EN (eV)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20,random_state=0)

X_train.shape, X_test.shape
# Out:
# ((172, 24), (44, 24))

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score
print("r2 on test data is",   r2_score(y_test, y_predict))
# Out:
# r2 on test data is 0.9483102784505787

# %%
print("RMSE:"+str(np.sqrt(mean_squared_error(y_test, y_predict))))
# Out:
# RMSE:0.26186732803873564

# %%
H_params = model.get_params()
H_params
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
from scipy.stats import uniform, randint
from sklearn.linear_model import Lasso
from scipy.stats.qmc import Sobol

# %%
from sklearn.model_selection import RandomizedSearchCV , GridSearchCV
import xgboost as xgb

params = { 'max_depth': np.arange(5,10,1),                     #13
           'learning_rate': np.arange(0.01,0.1, 0.005),      #0.325
           #'subsample': np.arange(0.95, 1.0, 0.05),             
           #'colsample_bytree': np.arange(0.99, 1, 0.01),        
           #'colsample_bylevel': np.arange(0.99, 1, 0.01),       
           'n_estimators': np.arange(300,800,10),                #450
           #'reg_alpha': uniform(0.05,2),                     #0.8612124738904751
           #'reg_lambda': uniform(0.05,2),                      #115.01455430429743  
         }
sobol_sequence = Sobol(1)
lasso = Lasso()
# number of times random search is run
n = 30                                             # n=20    #n_iter=50  #cv=10

# %%
xgbr = xgb.XGBRegressor(seed=20)
average = np.array([0]*24, dtype=np.float64)
feature_importances = []

nth_run = 1
rmse_values_test = []
rmse_values_train = []
avg = 0

for i in range(n):   
    clf = RandomizedSearchCV(estimator=xgbr,
                             param_distributions=params,
                             scoring='neg_mean_squared_error',
                             n_iter=30,cv=10,random_state=np.random.RandomState(int(sobol_sequence.random(1)[0] * 2**31)),
                             verbose=1)
    clf.fit(X_train,y_train)
    
    print(f"Run {i + 1}: Best Estimator: {clf.best_estimator_}")
    
    if (i + 1) % nth_run == 0:
        # Predictions on test set
        y_pred_test = clf.predict(X_test)
        mse_test = mean_squared_error(y_test, y_pred_test)
        rmse_test = np.sqrt(mse_test)
        rmse_values_test.append(rmse_test)
        
        # Predictions on training set
        y_pred_train = clf.predict(X_train)
        mse_train = mean_squared_error(y_train, y_pred_train)
        rmse_train = np.sqrt(mse_train)
        rmse_values_train.append(rmse_train)

        print(f"RMSE for every {nth_run}th run - Training: {rmse_train}, Test: {rmse_test}")
        nth_run += 1
    
    average += clf.best_estimator_.feature_importances_
    feature_importances.append(clf.best_estimator_.feature_importances_)
average = average/n
avg = avg/n
# Out:
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 1: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.024999999999999998,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 1th run - Training: 0.08374476576500584, Test: 0.27268048085084917
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 2: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.08999999999999998,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=620, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 2th run - Training: 0.003342179591344741, Test: 0.27098876701258906
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 3: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.08499999999999998,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=310, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 3th run - Training: 0.010239243254638115, Test: 0.28307308281723276
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 4: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.024999999999999998,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=360, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 4th run - Training: 0.07152348520095776, Test: 0.27050829755063355
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 5: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.019999999999999997,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=400, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 5th run - Training: 0.07562406426751639, Test: 0.2675845822843261
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 6: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.08499999999999998,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=670, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 6th run - Training: 0.003373626544899394, Test: 0.2832707247949671
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 7: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.08499999999999998,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=490, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 7th run - Training: 0.003373677466918209, Test: 0.2832707493092092
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 8: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.08999999999999998,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=750, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 8th run - Training: 0.003342173990815438, Test: 0.27098876693153845
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 9: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.015, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=410, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 9th run - Training: 0.09112572888316808, Test: 0.27618372208520464
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 10: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.015, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=550, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 10th run - Training: 0.0712266394336855, Test: 0.2728469404565415
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 11: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.019999999999999997,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=320, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 11th run - Training: 0.08976016165928576, Test: 0.2714739024799027
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 12: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.019999999999999997,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=400, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 12th run - Training: 0.07562406426751639, Test: 0.2675845822843261
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 13: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.015, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=330, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 13th run - Training: 0.1094803539757252, Test: 0.2779816907303675
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 14: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.024999999999999998,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=670, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 14th run - Training: 0.03321410085714158, Test: 0.27226879058588405
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 15: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.024999999999999998,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=310, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 15th run - Training: 0.08174837888376785, Test: 0.27218096750812076
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 16: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.034999999999999996,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=450, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 16th run - Training: 0.03613575306461054, Test: 0.26448718069293625
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 17: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=710, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 17th run - Training: 0.08425241139060602, Test: 0.2724324854171038
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 18: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.08999999999999998,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=370, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 18th run - Training: 0.004634582313465945, Test: 0.2708888313654381
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 19: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.08499999999999998,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=330, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 19th run - Training: 0.008289895364063323, Test: 0.28340869138697733
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 20: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.015, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=550, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 20th run - Training: 0.0712266394336855, Test: 0.2728469404565415
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 21: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.08499999999999998,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=720, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 21th run - Training: 0.003373623699965892, Test: 0.2832707247949671
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 22: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=720, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 22th run - Training: 0.08343099889094287, Test: 0.2721568145714893
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 23: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.06999999999999999,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=450, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 23th run - Training: 0.004852927695265252, Test: 0.278038000550144
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 24: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=440, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 24th run - Training: 0.12561946883067382, Test: 0.2847316711826493
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 25: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.08999999999999998,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 25th run - Training: 0.003342200538105989, Test: 0.2709887746134434
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 26: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.015, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=460, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 26th run - Training: 0.08535360464189172, Test: 0.2759852034616324
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 27: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=540, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 27th run - Training: 0.10392544931185616, Test: 0.27678371883125885
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 28: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=640, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 28th run - Training: 0.09045216747740124, Test: 0.27432163303493756
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 29: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.019999999999999997,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=540, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 29th run - Training: 0.055197217811257596, Test: 0.26461771880154583
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Run 30: Best Estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.034999999999999996,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=630, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# RMSE for every 30th run - Training: 0.014784562265115046, Test: 0.2663723491176256

# %%
np.min(rmse_values_test), np.max(rmse_values_test)
# Out:
# (0.26448718069293625, 0.2847316711826493)

# %%
np.min(rmse_values_train), np.max(rmse_values_train)
# Out:
# (0.003342173990815438, 0.12561946883067382)

# %%
mean_rmse_test = np.mean(rmse_values_test)
print(f"Mean RMSE: {mean_rmse_test}")
# Out:
# Mean RMSE: 0.2741405595320128

# %% [markdown]
# mean_rmse_train = np.mean(rmse_values_train)
# print(f"Mean RMSE: {mean_rmse_train}")
